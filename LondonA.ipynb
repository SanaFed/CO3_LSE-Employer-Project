# %% [markdown]
# # CENTRAL LONDON DATA SET

# %%
# Import all the necessary packages.
import pandas as pd
import numpy as np
from datetime import datetime

# Optional - Ignore warnings.
import warnings
warnings.filterwarnings('ignore')
  
# Read the provided CSV file/data set.            
london_central = pd.read_csv('Central London.csv') 

# View DataFrame.
london_central.head()
# Out:
#   Survey wave (calendar quarter) Equivalent financial quarter   Site ID  \
# 0        2014 Q1 (January-March)                   2013-14 Q4  CENCY001
# 1        2014 Q1 (January-March)                   2013-14 Q4  CENCY001
# 2        2014 Q1 (January-March)                   2013-14 Q4  CENCY001
# 3        2014 Q1 (January-March)                   2013-14 Q4  CENCY001
# 4        2014 Q1 (January-March)                   2013-14 Q4  CENCY001
#
#                              Location    Survey date Weather         Time  \
# 0  Millbank (south of Thorney Street)  ven, 24/01/14     Dry  0600 - 0615
# 1  Millbank (south of Thorney Street)  ven, 24/01/14     Dry  0615 - 0630
# 2  Millbank (south of Thorney Street)  ven, 24/01/14     Dry  0630 - 0645
# 3  Millbank (south of Thorney Street)  ven, 24/01/14     Dry  0645 - 0700
# 4  Millbank (south of Thorney Street)  ven, 24/01/14     Dry  0700 - 0715
#
#                         Period   Direction  Start hour  Start minute  \
# 0  Early Morning (06:00-07:00)  Northbound         6.0           0.0
# 1  Early Morning (06:00-07:00)  Northbound         6.0          15.0
# 2  Early Morning (06:00-07:00)  Northbound         6.0          30.0
# 3  Early Morning (06:00-07:00)  Northbound         6.0          45.0
# 4        AM peak (07:00-10:00)  Northbound         7.0           0.0
#
#    Number of private cycles  Number of cycle hire bikes  Total cycles  \
# 0                       0.0                         0.0           0.0
# 1                      15.0                         0.0          15.0
# 2                      35.0                         0.0          35.0
# 3                      59.0                         2.0          61.0
# 4                      73.0                         0.0          73.0
#
#    Unnamed: 14  Unnamed: 15  Unnamed: 16
# 0          NaN          NaN          NaN
# 1          NaN          NaN          NaN
# 2          NaN          NaN          NaN
# 3          NaN          NaN          NaN
# 4          NaN          NaN          NaN

# %%
# Any missing values?
london_central.isnull().sum()
# Out:
# Survey wave (calendar quarter)     290203
# Equivalent financial quarter       290203
# Site ID                            290203
# Location                           290203
# Survey date                        300359
# Weather                            302037
# Time                               290203
# Period                             290203
# Direction                          290203
# Start hour                         290203
# Start minute                       290203
# Number of private cycles           290267
# Number of cycle hire bikes         290267
# Total cycles                       290203
# Unnamed: 14                       1048366
# Unnamed: 15                       1048366
# Unnamed: 16                       1048366
# dtype: int64

# %%
# Explore the data.
london_central.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1048366 entries, 0 to 1048365
# Data columns (total 17 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   Survey wave (calendar quarter)  758163 non-null  object
#  1   Equivalent financial quarter    758163 non-null  object
#  2   Site ID                         758163 non-null  object
#  3   Location                        758163 non-null  object
#  4   Survey date                     748007 non-null  object
#  5   Weather                         746329 non-null  object
#  6   Time                            758163 non-null  object
#  7   Period                          758163 non-null  object
#  8   Direction                       758163 non-null  object
#  9   Start hour                      758163 non-null  float64
#  10  Start minute                    758163 non-null  float64
#  11  Number of private cycles        758099 non-null  float64
#  12  Number of cycle hire bikes      758099 non-null  float64
#  13  Total cycles                    758163 non-null  float64
#  14  Unnamed: 14                     0 non-null       float64
#  15  Unnamed: 15                     0 non-null       float64
#  16  Unnamed: 16                     0 non-null       float64
# dtypes: float64(8), object(9)
# memory usage: 136.0+ MB

# %%
# Drop last three columns as contain no values.
L_centr_fnl = london_central.drop(columns=['Unnamed: 14', 'Unnamed: 15', 'Unnamed: 16']).reset_index(drop=True)

# View DataFrame.
print(L_centr_fnl.shape)
L_centr_fnl.head()
# Out:
# (1048366, 14)
#   Survey wave (calendar quarter) Equivalent financial quarter   Site ID  \
# 0        2014 Q1 (January-March)                   2013-14 Q4  CENCY001
# 1        2014 Q1 (January-March)                   2013-14 Q4  CENCY001
# 2        2014 Q1 (January-March)                   2013-14 Q4  CENCY001
# 3        2014 Q1 (January-March)                   2013-14 Q4  CENCY001
# 4        2014 Q1 (January-March)                   2013-14 Q4  CENCY001
#
#                              Location    Survey date Weather         Time  \
# 0  Millbank (south of Thorney Street)  ven, 24/01/14     Dry  0600 - 0615
# 1  Millbank (south of Thorney Street)  ven, 24/01/14     Dry  0615 - 0630
# 2  Millbank (south of Thorney Street)  ven, 24/01/14     Dry  0630 - 0645
# 3  Millbank (south of Thorney Street)  ven, 24/01/14     Dry  0645 - 0700
# 4  Millbank (south of Thorney Street)  ven, 24/01/14     Dry  0700 - 0715
#
#                         Period   Direction  Start hour  Start minute  \
# 0  Early Morning (06:00-07:00)  Northbound         6.0           0.0
# 1  Early Morning (06:00-07:00)  Northbound         6.0          15.0
# 2  Early Morning (06:00-07:00)  Northbound         6.0          30.0
# 3  Early Morning (06:00-07:00)  Northbound         6.0          45.0
# 4        AM peak (07:00-10:00)  Northbound         7.0           0.0
#
#    Number of private cycles  Number of cycle hire bikes  Total cycles
# 0                       0.0                         0.0           0.0
# 1                      15.0                         0.0          15.0
# 2                      35.0                         0.0          35.0
# 3                      59.0                         2.0          61.0
# 4                      73.0                         0.0          73.0

# %%
# Drop the rows where all elements are missing.
L_centr_fnl_0 = L_centr_fnl.dropna(how='all')

# View DataFrame.
print(L_centr_fnl_0.shape)
L_centr_fnl_0.head()
# Out:
# (758163, 14)
#   Survey wave (calendar quarter) Equivalent financial quarter   Site ID  \
# 0        2014 Q1 (January-March)                   2013-14 Q4  CENCY001
# 1        2014 Q1 (January-March)                   2013-14 Q4  CENCY001
# 2        2014 Q1 (January-March)                   2013-14 Q4  CENCY001
# 3        2014 Q1 (January-March)                   2013-14 Q4  CENCY001
# 4        2014 Q1 (January-March)                   2013-14 Q4  CENCY001
#
#                              Location    Survey date Weather         Time  \
# 0  Millbank (south of Thorney Street)  ven, 24/01/14     Dry  0600 - 0615
# 1  Millbank (south of Thorney Street)  ven, 24/01/14     Dry  0615 - 0630
# 2  Millbank (south of Thorney Street)  ven, 24/01/14     Dry  0630 - 0645
# 3  Millbank (south of Thorney Street)  ven, 24/01/14     Dry  0645 - 0700
# 4  Millbank (south of Thorney Street)  ven, 24/01/14     Dry  0700 - 0715
#
#                         Period   Direction  Start hour  Start minute  \
# 0  Early Morning (06:00-07:00)  Northbound         6.0           0.0
# 1  Early Morning (06:00-07:00)  Northbound         6.0          15.0
# 2  Early Morning (06:00-07:00)  Northbound         6.0          30.0
# 3  Early Morning (06:00-07:00)  Northbound         6.0          45.0
# 4        AM peak (07:00-10:00)  Northbound         7.0           0.0
#
#    Number of private cycles  Number of cycle hire bikes  Total cycles
# 0                       0.0                         0.0           0.0
# 1                      15.0                         0.0          15.0
# 2                      35.0                         0.0          35.0
# 3                      59.0                         2.0          61.0
# 4                      73.0                         0.0          73.0

# %%
# Check missing values.
L_centr_fnl_0.isnull().sum()
# Out:
# Survey wave (calendar quarter)        0
# Equivalent financial quarter          0
# Site ID                               0
# Location                              0
# Survey date                       10156
# Weather                           11834
# Time                                  0
# Period                                0
# Direction                             0
# Start hour                            0
# Start minute                          0
# Number of private cycles             64
# Number of cycle hire bikes           64
# Total cycles                          0
# dtype: int64

# %% [markdown]
# ## Cleaning Weather Column
#
# The original London Central data was edited in Excel. Looking at the below code can see there is 283 different classifications for weather. Looking into the Excel file can see that there are a lot of Weather classifications some which are the same just spelt differently and some which are spelt incorrectly. This needs cleaning to categorise the data better and improve processes.

# %%
# Check for unique values.
L_centr_fnl_0['Weather'].nunique()
# Out:
# 283

# %%
# Change relevant values to Cloudy
L_centr_fnl_0['Weather'] = L_centr_fnl_0['Weather'].replace(['Cloudy/dry', 'Cloudy And Warm', 
                                                               'Dry/cloudy', 'Overcast', 
                                                          'Overcast And Dull','Partly Cloudy'], 
                                                         'Cloudy')

# %%
# Check that values have been changed
L_centr_fnl_0[L_centr_fnl_0['Weather'] == 'Cloudy And Warm']
# Out:
# Empty DataFrame
# Columns: [Survey wave (calendar quarter), Equivalent financial quarter, Site ID, Location, Survey date, Weather, Time, Period, Direction, Start hour, Start minute, Number of private cycles, Number of cycle hire bikes, Total cycles]
# Index: []

# %%
# Change relevant values to Cold
L_centr_fnl_0['Weather'] = L_centr_fnl_0['Weather'].replace(['Cold Dry', 'Coldish', 'Cold/dry', 'Dry/cold',
                                                               'Dry & Cold','Fine Cold', 'Fine V Cold',
                                                              'Now Starts To Get Chilly', 'Very Cold/dry'], 
                                                         'Cold')

# %%
# Change relevant values to Damp
L_centr_fnl_0['Weather'] = L_centr_fnl_0['Weather'].replace(['Almost Dry'], 'Damp')

# %%
# Change relevant values to Dark
L_centr_fnl_0['Weather'] = L_centr_fnl_0['Weather'].replace(['Dark Sunny', 'Dry Dark', 'Dark Dry'],
                                                             'Dark')

# %%
# Change relevant values to Dry
L_centr_fnl_0['Weather'] = L_centr_fnl_0['Weather'].replace(['2 Snowflakes Otherwise Dry',
                                                              'A Bit Chilly At First', 'dry', 'Ddry',
                                                              'Drty', 'Dry & Mild', 'Dry 3/4 Dry',
                                                              'Dry And Fine', 'Dry And Overcast',
                                                              'Dry But Rain Threatening', 'Dry Fri',
                                                              'Dry Mon', 'Dry Thu', 'Dry Wed', 'Dry Y',
                                                              'Dry/good', 'Dry/sunny/cold', 'Drying Up',
                                                              'Dryish', 'Dull', 'Dy', 'Fair', 'Fine',
                                                              'Fine + Dry Chilly At First', 'Fine And Dry',
                                                              'Good/dry', 'Kdry', 'Mild', 'Rain Looking Likely',
                                                              'Rain Stopped', 'Rain Stopped-dry'], 'Dry')

# %%
# Change relevant values Dry & Rain
L_centr_fnl_0['Weather'] = L_centr_fnl_0['Weather'].replace(['Cold & Dry Early Rain Later',
                                                              'Dry - Rain', 'Rain Dry', 'Rain/dry']
                                                              , 'Dry & Rain')

# %%
# Change relevant values to Dry & Wet
L_centr_fnl_0['Weather'] = L_centr_fnl_0['Weather'].replace(['Dry - Wet', 'Dry + Wet',
                                                              'Dry + Wet', 'Dry A.m Wet P.m',
                                                              'Dry But Wet Road', 'Dry But Wet Roads',
                                                              'Dry Road Still Wet', 'Dry Road Wet With Leaves',
                                                              'Dry Wet Road', 'Dry-Wet', 'Dry-wet', 'Dry/wet Road Surface',
                                                              'Wet - Dry', 'Wet + Dry', 'Wet First Then Dry', 
                                                              'Wet-dry', 'Wet/ Dry', 'Wet/dry', 'Wetr First Then Dry',
                                                              'Dry/wet'], 'Dry & Wet')

# %%
# Change relevant value to Frost / Fog
L_centr_fnl_0['Weather'] = L_centr_fnl_0['Weather'].replace(['Dry (frost & Fog)', 'Foggy',
                                                              'Foogy/v Cold', 'Foggy/v Cold'], 'Frost / Fog')

# %%
# Change relevant value to Hail / Sleet
L_centr_fnl_0['Weather'] = L_centr_fnl_0['Weather'].replace(['Cloudy/hail', 'Hail', 'Hail',
                                                              'Hail Shower', 'Sleet', 
                                                               'Wet Light Hailstone'], 'Hail / Sleet')

# %%
# Change relevant values to Heavy Rain
L_centr_fnl_0['Weather'] = L_centr_fnl_0['Weather'].replace(['Deluge', 'Down Pour',
                                                              'H Rain', 'Rain-heavy', 
                                                              'Very Heavy Rain'], 'Heavy Rain')

# %%
# Change relevant values to Hot
L_centr_fnl_0['Weather'] = L_centr_fnl_0['Weather'].replace(['Dry/hot', 'Hot + Humid',
                                                              'Hot And Humid', 'Hot And Sunny',
                                                              'Hot/dry', 'Very Hot Dry'], 'Hot')

# %%
# Change relevant values to Light Rain
L_centr_fnl_0['Weather'] = L_centr_fnl_0['Weather'].replace(['(drizzle)', 'A Few Drops Of Rain',
                                                              'A Few Rain Showers', 'Cloudy/drizzle',
                                                              'Cold/showery', 'Damp & Drizzly', 'Drizzle',
                                                              'Drizzle Damp', 'Drizzle/rain', 'Drizzle/showers',
                                                              'Drizzle/wet', 'Drizzling', 'Drizzly', 'Drizzly Rain',
                                                              'Dry (+brief Speels Of Drizzle)', 'Dry With Intermitent Rain', 'Dry/drizzle',  
                                                              'Dry/drizzly', 'Fine Drizzle', 'Intermitent Light Rain',
                                                              'Intermitent Light Showers', 'Light Drizzle', 'Light Shower',
                                                              'Light Showers', 'Light Showers Inc Some Hail', 'Light Shrs',
                                                              'Lt Rain', 'Shower', 'Shower/wet', 'Showers', 'Showers Mix',
                                                              'Showery', 'Slight Drizzle', 'Slight Drizzle Till End', 'Some Showers',
                                                              'Spitting', 'Spitting ', 'V Cold Showers', 'V Light Drizzle', 'V Light Rain',
                                                              'V Light Showers', 'V Light Shrs', 'V Lt Rain', 'V. Light Rain',
                                                              'V.light Drizzle', 'V.light Rain', 'Very Light Rain', 'V.wet', 
                                                              'Very Light Drizzle', 'Wet Drizzle',
                                                              'Wet/drizzle', 'Wet/light Showers'], 'Light Rain')

# %%
# Change relevant values to Mist
L_centr_fnl_0['Weather'] = L_centr_fnl_0['Weather'].replace(['Damp/misty', 'Damp/misty/wet'],
                                                             'Mist')

# %%
# Change relevant values to Rain
L_centr_fnl_0['Weather'] = L_centr_fnl_0['Weather'].replace(['(rain After)', 'Cloud/rain',
                                                              'Cloudy/ Rain', 'Cloudy/rain',
                                                              'Cold/ Rain', 'Cold/rain',
                                                              'Damp - Rain', 'Heavy Shower',
                                                              'Heavy Showers', 'Heavy Showers Throughout Day',
                                                              'L/rain', 'Rain Damp',
                                                              'Rain/cloudy', 'Rain/drizzle',
                                                              'Rain/wind', 'Rains', 'Rainy', 'Some Heavy Showers',
                                                              'Steady Rain', 'Wet/rain'], 'Rain')

# %%
# Change relevant values to Snow
L_centr_fnl_0['Weather'] = L_centr_fnl_0['Weather'].replace(['Heavy Snow', 'Occasional Lt Snow Shrs',
                                                              'Snowing', 'Wet/ Snowing'], 'Snow')

# %%
# Change relevant values to Sun
L_centr_fnl_0['Weather'] = L_centr_fnl_0['Weather'].replace(['Cloudy/sunny', 'Dry & Sunny',
                                                              'Dry + Sunny', 'Dry And Sunny',
                                                              'Dry Sunny', 'Dry/sunny', 'Fine & Sunny',
                                                              'Hot & Sunny', 'Mild And Sunny',
                                                              'Road Drying Sun Out', 'Sun/clouds',
                                                              'Sun/cloudy', 'Sunny', 'Sunny Cloudy',
                                                              'Sunny Cold', 'Sunny Periods And Warm',
                                                              'Sunny/cloudy', 'Sunny/dry',
                                                              'Warm & Sunny Chilly Later', 
                                                               'Warm + Sunny'], 'Sun')

# %%
# Change relevant values to Sun & Rain
L_centr_fnl_0['Weather'] = L_centr_fnl_0['Weather'].replace(['Cold Sunny Rain', 'Sun/rain',
                                                              'Sunny/rainy'], 'Sun & Wet')

# %%
# Change relevant values to Sun & Wet
L_centr_fnl_0['Weather'] = L_centr_fnl_0['Weather'].replace(['Wet/sunny'], 'Sun & Wet')

# %%
# Change relevant values to Sun & Wind
L_centr_fnl_0['Weather'] = L_centr_fnl_0['Weather'].replace(['Sunny & Windy', 'Sunny But Very Windy',
                                                              'Sunny Until Evening But Windy',
                                                              'Very Cold Sunny But Windy',
                                                              'Warm + Sunny Cloudy + Windy',
                                                              'Warm Sunny And Windy',
                                                              'Warm & Sunny But Windy & Cold'], 'Sun & Wind')

# %%
# Change relevant values to Unknown
L_centr_fnl_0['Weather'] = L_centr_fnl_0['Weather'].replace(['D', 'Wed', 'X'], 'Unknown')

# %%
# Change relevant values to Warm
L_centr_fnl_0['Weather'] = L_centr_fnl_0['Weather'].replace(['Cold At First Then Warm/sunny',
                                                              'Dry And Warm', 'Warm + Dry',
                                                              'Warm And Humid', 'Warm And Overcast'],
                                                             'Warm')

# %%
# Change relevant values to Warm & Wind 
L_centr_fnl_0['Weather'] = L_centr_fnl_0['Weather'].replace(['Warm With A Slight Wind',
                                                              'Warm And Windy'], 'Warm & Wind')

# %%
# Change relevant values to Wet
L_centr_fnl_0['Weather'] = L_centr_fnl_0['Weather'].replace(['Getting Wet', 'No Rain Wet Roads',
                                                              'Really Wet', 'Road Wet', 'S. Wet',
                                                              'Slightly Wet', 'V Wet', 'V. Wet',
                                                              'Very Wet', 'Wert', 'Wet (spitting)',
                                                              'Wet (windy)', 'Wet Again', 'Wet Damp',
                                                              'Wet Intermittently', 'Wet Road', 'Wet T',
                                                              'Wet/cloudy', 'Wet/damp', 'Wetish', 
                                                              'Wetr', 'Wetter', 'Winds Rather Chilly', 'Wet '],
                                                             'Wet')

# %%
# Change relevant values to Wet & Wind
L_centr_fnl_0['Weather'] = L_centr_fnl_0['Weather'].replace(['Wet And Very Windy',
                                                              'Wet And Windy',
                                                              'Wet & Windy',
                                                              'Wet + Windy'], 'Wet & Wind')

# %%
# Change relevant values to Wind
L_centr_fnl_0['Weather'] = L_centr_fnl_0['Weather'].replace(['Blustery', 'Cloudy/windy',
                                                              'Cold Wind', 'Cold Windy Dry',
                                                              'Dry (windy)', 'Dry & Very Windy',
                                                              'Dry And Very Windy', 'Dry And Windy',
                                                              'Dry Windy', 'Dry/gusty', 'Dry/very Windy',
                                                              'Dry/windy', 'Dry/windy/strong Wind',
                                                              'Fine (windy)', 'Fine Windy',
                                                              'High Winds & Spits Of Rain',
                                                              'Periods of Rain Quite Windy',
                                                              'Very Windy & Cold', 'Windy',
                                                              'Windy Dry', 'Windy Showery',
                                                              'Windy/cloidy', 'Windy/cloudy', 'Windy/drizzle',
                                                              'Windy/dry', 'Cold Then Dry And Windy',
                                                              'Dry & Windy', 'Dry But A Bit Windy'], 'Wind')

# %%
# Change relevant values to Wind & Rain
L_centr_fnl_0['Weather'] = L_centr_fnl_0['Weather'].replace(['Windy/ Rain',
                                                              'Periods Of Rain Quite Windy'], 'Wind & Rain')

# %%
# Check unique values.
print(L_centr_fnl_0['Weather'].nunique())
L_centr_fnl_0['Weather'].value_counts()
# Out:
# 30
# Dry                              641187
# Wet                               79468
# Rain                               6916
# Cloudy                             4872
# Sun                                3928
# Light Rain                         3540
# Wind                               1232
# Dry & Wet                          1212
# Cold                                912
# Damp                                643
# Hot                                 412
# Sun & Wind                          278
# Sun & Wet                           234
# Snow                                192
# Warm                                190
# Dry & Rain                          147
# Wet & Wind                          142
# Frost / Fog                         138
# Unknown                             134
# Wind & Rain                         128
# Warm & Wind                         112
# Heavy Rain                          106
# Hail / Sleet                         88
# Hazy                                 64
# Dark                                 18
# Dry (+brief Speels Of Drizzle        16
# Mist                                 12
# Storm                                 4
# Rain & Thunder                        2
# Thunder                               2
# Name: Weather, dtype: int64

# %% [markdown]
# ### Missing values in Weather Column

# %%
# Subset of the data of only null values
null_data = L_centr_fnl_0[L_centr_fnl_0.isna().any(axis=1)]

# Subset of null data frame to look weather null values 
# Wanted to see if there was a sensible way to replace the null based on loc or quarter
weather_null = null_data[['Location', 'Survey wave (calendar quarter)', 'Weather']]
weather_null
# Out:
#                 Location Survey wave (calendar quarter) Weather
# 35264          York Road           2014 Q2 (April-June)     NaN
# 35265          York Road           2014 Q2 (April-June)     NaN
# 35266          York Road           2014 Q2 (April-June)     NaN
# 35267          York Road           2014 Q2 (April-June)     NaN
# 35268          York Road           2014 Q2 (April-June)     NaN
# ...                  ...                            ...     ...
# 718838  Grosvenor Street       2021 Q3 (July-September)     Dry
# 718839  Grosvenor Street       2021 Q3 (July-September)     Dry
# 718840  Grosvenor Street       2021 Q3 (July-September)     Dry
# 718841  Grosvenor Street       2021 Q3 (July-September)     Dry
# 718842  Grosvenor Street       2021 Q3 (July-September)     Dry
#
# [14846 rows x 3 columns]

# %%
# All the entries with null weather data 
w_null = weather_null[weather_null['Weather'].isna()]

# Check which locations have the most NaN values 
print(w_null['Location'].value_counts())
# Out:
# Welbeck Street                               256
# Wimpole Street                               256
# Blackfriars Road                             256
# Buckingham Gate                              256
# Millbank (north of Great Peter Street)       256
#                                             ...
# Hastings Street                               46
# Old Compton Street                            40
# Black Prince Road (east of Gibson Street)      8
# Great Queen Street                             2
# Goswell Road (south)                           2
# Name: Location, Length: 86, dtype: int64

# %% [markdown]
# ## Cleaning Date and Time related Columns

# %%
# Split 'Survey wave (calendar quarter)' column into three new columns.
L_centr_fnl_0['Survey_wave_year'] = L_centr_fnl_0['Survey wave (calendar quarter)'].str.split(' ', expand = True)[0]
L_centr_fnl_0['Survey_wave_quater'] = L_centr_fnl_0['Survey wave (calendar quarter)'].str.split(' ', expand = True)[1]
L_centr_fnl_0['Survey_wave_months'] = L_centr_fnl_0['Survey wave (calendar quarter)'].str.split(' ', expand = True)[2]

# View DataFrame.
L_centr_fnl_0.head()
# Out:
#   Survey wave (calendar quarter) Equivalent financial quarter   Site ID  \
# 0        2014 Q1 (January-March)                   2013-14 Q4  CENCY001
# 1        2014 Q1 (January-March)                   2013-14 Q4  CENCY001
# 2        2014 Q1 (January-March)                   2013-14 Q4  CENCY001
# 3        2014 Q1 (January-March)                   2013-14 Q4  CENCY001
# 4        2014 Q1 (January-March)                   2013-14 Q4  CENCY001
#
#                              Location    Survey date Weather         Time  \
# 0  Millbank (south of Thorney Street)  ven, 24/01/14     Dry  0600 - 0615
# 1  Millbank (south of Thorney Street)  ven, 24/01/14     Dry  0615 - 0630
# 2  Millbank (south of Thorney Street)  ven, 24/01/14     Dry  0630 - 0645
# 3  Millbank (south of Thorney Street)  ven, 24/01/14     Dry  0645 - 0700
# 4  Millbank (south of Thorney Street)  ven, 24/01/14     Dry  0700 - 0715
#
#                         Period   Direction  Start hour  Start minute  \
# 0  Early Morning (06:00-07:00)  Northbound         6.0           0.0
# 1  Early Morning (06:00-07:00)  Northbound         6.0          15.0
# 2  Early Morning (06:00-07:00)  Northbound         6.0          30.0
# 3  Early Morning (06:00-07:00)  Northbound         6.0          45.0
# 4        AM peak (07:00-10:00)  Northbound         7.0           0.0
#
#    Number of private cycles  Number of cycle hire bikes  Total cycles  \
# 0                       0.0                         0.0           0.0
# 1                      15.0                         0.0          15.0
# 2                      35.0                         0.0          35.0
# 3                      59.0                         2.0          61.0
# 4                      73.0                         0.0          73.0
#
#   Survey_wave_year Survey_wave_quater Survey_wave_months
# 0             2014                 Q1    (January-March)
# 1             2014                 Q1    (January-March)
# 2             2014                 Q1    (January-March)
# 3             2014                 Q1    (January-March)
# 4             2014                 Q1    (January-March)

# %%
# Remove brackets in 'Survey_wave_months' column.
L_centr_fnl_0['Survey_wave_months'] = L_centr_fnl_0['Survey_wave_months'].str.replace('(','')
L_centr_fnl_0['Survey_wave_months'] = L_centr_fnl_0['Survey_wave_months'].str.replace(')','')

# View DataFrame
L_centr_fnl_0.head()
# Out:
#   Survey wave (calendar quarter) Equivalent financial quarter   Site ID  \
# 0        2014 Q1 (January-March)                   2013-14 Q4  CENCY001
# 1        2014 Q1 (January-March)                   2013-14 Q4  CENCY001
# 2        2014 Q1 (January-March)                   2013-14 Q4  CENCY001
# 3        2014 Q1 (January-March)                   2013-14 Q4  CENCY001
# 4        2014 Q1 (January-March)                   2013-14 Q4  CENCY001
#
#                              Location    Survey date Weather         Time  \
# 0  Millbank (south of Thorney Street)  ven, 24/01/14     Dry  0600 - 0615
# 1  Millbank (south of Thorney Street)  ven, 24/01/14     Dry  0615 - 0630
# 2  Millbank (south of Thorney Street)  ven, 24/01/14     Dry  0630 - 0645
# 3  Millbank (south of Thorney Street)  ven, 24/01/14     Dry  0645 - 0700
# 4  Millbank (south of Thorney Street)  ven, 24/01/14     Dry  0700 - 0715
#
#                         Period   Direction  Start hour  Start minute  \
# 0  Early Morning (06:00-07:00)  Northbound         6.0           0.0
# 1  Early Morning (06:00-07:00)  Northbound         6.0          15.0
# 2  Early Morning (06:00-07:00)  Northbound         6.0          30.0
# 3  Early Morning (06:00-07:00)  Northbound         6.0          45.0
# 4        AM peak (07:00-10:00)  Northbound         7.0           0.0
#
#    Number of private cycles  Number of cycle hire bikes  Total cycles  \
# 0                       0.0                         0.0           0.0
# 1                      15.0                         0.0          15.0
# 2                      35.0                         0.0          35.0
# 3                      59.0                         2.0          61.0
# 4                      73.0                         0.0          73.0
#
#   Survey_wave_year Survey_wave_quater Survey_wave_months
# 0             2014                 Q1      January-March
# 1             2014                 Q1      January-March
# 2             2014                 Q1      January-March
# 3             2014                 Q1      January-March
# 4             2014                 Q1      January-March

# %%
# Change dtype of 'Survey_wave_year' column to integer.
L_centr_fnl_0['Survey_wave_year'] = L_centr_fnl_0['Survey_wave_year'].astype(int)

# %%
# Replace blank values with NaN in 'Survey date' column.
L_centr_fnl_0['Survey date'] = L_centr_fnl_0['Survey date'].replace(r'^\s*$', np.nan, regex=True)

# %%
# Split 'Survey date' column into two new columns.
L_centr_fnl_0[['Survey_week_day', 'Survey_date']] = L_centr_fnl_0['Survey date'].\
apply(lambda x: pd.Series(str(x).split(',')))

# View DataFrame.
L_centr_fnl_0.head()
# Out:
#   Survey wave (calendar quarter) Equivalent financial quarter   Site ID  \
# 0        2014 Q1 (January-March)                   2013-14 Q4  CENCY001
# 1        2014 Q1 (January-March)                   2013-14 Q4  CENCY001
# 2        2014 Q1 (January-March)                   2013-14 Q4  CENCY001
# 3        2014 Q1 (January-March)                   2013-14 Q4  CENCY001
# 4        2014 Q1 (January-March)                   2013-14 Q4  CENCY001
#
#                              Location    Survey date Weather         Time  \
# 0  Millbank (south of Thorney Street)  ven, 24/01/14     Dry  0600 - 0615
# 1  Millbank (south of Thorney Street)  ven, 24/01/14     Dry  0615 - 0630
# 2  Millbank (south of Thorney Street)  ven, 24/01/14     Dry  0630 - 0645
# 3  Millbank (south of Thorney Street)  ven, 24/01/14     Dry  0645 - 0700
# 4  Millbank (south of Thorney Street)  ven, 24/01/14     Dry  0700 - 0715
#
#                         Period   Direction  Start hour  Start minute  \
# 0  Early Morning (06:00-07:00)  Northbound         6.0           0.0
# 1  Early Morning (06:00-07:00)  Northbound         6.0          15.0
# 2  Early Morning (06:00-07:00)  Northbound         6.0          30.0
# 3  Early Morning (06:00-07:00)  Northbound         6.0          45.0
# 4        AM peak (07:00-10:00)  Northbound         7.0           0.0
#
#    Number of private cycles  Number of cycle hire bikes  Total cycles  \
# 0                       0.0                         0.0           0.0
# 1                      15.0                         0.0          15.0
# 2                      35.0                         0.0          35.0
# 3                      59.0                         2.0          61.0
# 4                      73.0                         0.0          73.0
#
#    Survey_wave_year Survey_wave_quater Survey_wave_months Survey_week_day  \
# 0              2014                 Q1      January-March             ven
# 1              2014                 Q1      January-March             ven
# 2              2014                 Q1      January-March             ven
# 3              2014                 Q1      January-March             ven
# 4              2014                 Q1      January-March             ven
#
#   Survey_date
# 0    24/01/14
# 1    24/01/14
# 2    24/01/14
# 3    24/01/14
# 4    24/01/14

# %%
# Drop 'Survey_week_day' column.
L_centr_fnl_0 = L_centr_fnl_0.drop(columns='Survey_week_day').reset_index(drop=True)

# %%
# Remove whitespaces in 'Survey_date' column.
L_centr_fnl_0['Survey_date'] = L_centr_fnl_0['Survey_date'].str.replace(' ', '')

# %%
# Convert 'Survey_date' column to datetime dtype.
L_centr_fnl_0['Survey_date_dt'] = pd.to_datetime(L_centr_fnl_0['Survey_date'], format = '%d/%m/%y')

# View DataFrame.
L_centr_fnl_0.head()
# Out:
#   Survey wave (calendar quarter) Equivalent financial quarter   Site ID  \
# 0        2014 Q1 (January-March)                   2013-14 Q4  CENCY001
# 1        2014 Q1 (January-March)                   2013-14 Q4  CENCY001
# 2        2014 Q1 (January-March)                   2013-14 Q4  CENCY001
# 3        2014 Q1 (January-March)                   2013-14 Q4  CENCY001
# 4        2014 Q1 (January-March)                   2013-14 Q4  CENCY001
#
#                              Location    Survey date Weather         Time  \
# 0  Millbank (south of Thorney Street)  ven, 24/01/14     Dry  0600 - 0615
# 1  Millbank (south of Thorney Street)  ven, 24/01/14     Dry  0615 - 0630
# 2  Millbank (south of Thorney Street)  ven, 24/01/14     Dry  0630 - 0645
# 3  Millbank (south of Thorney Street)  ven, 24/01/14     Dry  0645 - 0700
# 4  Millbank (south of Thorney Street)  ven, 24/01/14     Dry  0700 - 0715
#
#                         Period   Direction  Start hour  Start minute  \
# 0  Early Morning (06:00-07:00)  Northbound         6.0           0.0
# 1  Early Morning (06:00-07:00)  Northbound         6.0          15.0
# 2  Early Morning (06:00-07:00)  Northbound         6.0          30.0
# 3  Early Morning (06:00-07:00)  Northbound         6.0          45.0
# 4        AM peak (07:00-10:00)  Northbound         7.0           0.0
#
#    Number of private cycles  Number of cycle hire bikes  Total cycles  \
# 0                       0.0                         0.0           0.0
# 1                      15.0                         0.0          15.0
# 2                      35.0                         0.0          35.0
# 3                      59.0                         2.0          61.0
# 4                      73.0                         0.0          73.0
#
#    Survey_wave_year Survey_wave_quater Survey_wave_months Survey_date  \
# 0              2014                 Q1      January-March    24/01/14
# 1              2014                 Q1      January-March    24/01/14
# 2              2014                 Q1      January-March    24/01/14
# 3              2014                 Q1      January-March    24/01/14
# 4              2014                 Q1      January-March    24/01/14
#
#   Survey_date_dt
# 0     2014-01-24
# 1     2014-01-24
# 2     2014-01-24
# 3     2014-01-24
# 4     2014-01-24

# %%
# Remove whitespaces in 'Survey wave (calendar quarter)' column.
L_centr_fnl_0['Year-Quarter'] = L_centr_fnl_0['Survey wave (calendar quarter)'].str.replace(' ', '')

# %%
# Divide year and quarter by '-'.
L_centr_fnl_0['Year-Quarter'] = L_centr_fnl_0['Year-Quarter'].astype(str).str[:4] + '-' + L_centr_fnl_0['Year-Quarter'].\
astype(str).str[4:6]

# %%
# Check missing values.
L_centr_fnl_0.isnull().sum()
# Out:
# Survey wave (calendar quarter)        0
# Equivalent financial quarter          0
# Site ID                               0
# Location                              0
# Survey date                       10412
# Weather                           11834
# Time                                  0
# Period                                0
# Direction                             0
# Start hour                            0
# Start minute                          0
# Number of private cycles             64
# Number of cycle hire bikes           64
# Total cycles                          0
# Survey_wave_year                      0
# Survey_wave_quater                    0
# Survey_wave_months                    0
# Survey_date                       10412
# Survey_date_dt                    10412
# Year-Quarter                          0
# dtype: int64

# %%
# Check dtypes.
L_centr_fnl_0.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 758163 entries, 0 to 758162
# Data columns (total 20 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   Survey wave (calendar quarter)  758163 non-null  object
#  1   Equivalent financial quarter    758163 non-null  object
#  2   Site ID                         758163 non-null  object
#  3   Location                        758163 non-null  object
#  4   Survey date                     747751 non-null  object
#  5   Weather                         746329 non-null  object
#  6   Time                            758163 non-null  object
#  7   Period                          758163 non-null  object
#  8   Direction                       758163 non-null  object
#  9   Start hour                      758163 non-null  float64
#  10  Start minute                    758163 non-null  float64
#  11  Number of private cycles        758099 non-null  float64
#  12  Number of cycle hire bikes      758099 non-null  float64
#  13  Total cycles                    758163 non-null  float64
#  14  Survey_wave_year                758163 non-null  int64
#  15  Survey_wave_quater              758163 non-null  object
#  16  Survey_wave_months              758163 non-null  object
#  17  Survey_date                     747751 non-null  object
#  18  Survey_date_dt                  747751 non-null  datetime64[ns]
#  19  Year-Quarter                    758163 non-null  object
# dtypes: datetime64[ns](1), float64(5), int64(1), object(13)
# memory usage: 115.7+ MB

# %% [markdown]
# ### Missing values in Date and Time related columns

# %%
# Select rows containing missing values in 'Survey_date_dt' column.
L_centr_fnl_1 = L_centr_fnl_0[L_centr_fnl_0['Survey_date_dt'].isnull()]

# View DataFrame.
L_centr_fnl_1.head()
# Out:
#        Survey wave (calendar quarter) Equivalent financial quarter   Site ID  \
# 114368        2015 Q1 (January-March)                   2014-15 Q4  CENCY094
# 114369        2015 Q1 (January-March)                   2014-15 Q4  CENCY094
# 114370        2015 Q1 (January-March)                   2014-15 Q4  CENCY094
# 114371        2015 Q1 (January-March)                   2014-15 Q4  CENCY094
# 114372        2015 Q1 (January-March)                   2014-15 Q4  CENCY094
#
#            Location Survey date Weather         Time  \
# 114368  Houndsditch         NaN     NaN  0600 - 0615
# 114369  Houndsditch         NaN     NaN  0615 - 0630
# 114370  Houndsditch         NaN     NaN  0630 - 0645
# 114371  Houndsditch         NaN     NaN  0645 - 0700
# 114372  Houndsditch         NaN     NaN  0700 - 0715
#
#                              Period  Direction  Start hour  Start minute  \
# 114368  Early Morning (06:00-07:00)  Eastbound         6.0           0.0
# 114369  Early Morning (06:00-07:00)  Eastbound         6.0          15.0
# 114370  Early Morning (06:00-07:00)  Eastbound         6.0          30.0
# 114371  Early Morning (06:00-07:00)  Eastbound         6.0          45.0
# 114372        AM peak (07:00-10:00)  Eastbound         7.0           0.0
#
#         Number of private cycles  Number of cycle hire bikes  Total cycles  \
# 114368                       2.0                         1.0           3.0
# 114369                       2.0                         1.0           3.0
# 114370                       2.0                         0.0           2.0
# 114371                       2.0                         0.0           2.0
# 114372                       5.0                         1.0           6.0
#
#         Survey_wave_year Survey_wave_quater Survey_wave_months Survey_date  \
# 114368              2015                 Q1      January-March         NaN
# 114369              2015                 Q1      January-March         NaN
# 114370              2015                 Q1      January-March         NaN
# 114371              2015                 Q1      January-March         NaN
# 114372              2015                 Q1      January-March         NaN
#
#        Survey_date_dt Year-Quarter
# 114368            NaT      2015-Q1
# 114369            NaT      2015-Q1
# 114370            NaT      2015-Q1
# 114371            NaT      2015-Q1
# 114372            NaT      2015-Q1

# %%
# View number of missing values in 'Survey_date_dt' column by calendar quarter.
L_centr_fnl_1['Survey wave (calendar quarter)'].value_counts().sort_index()
# Out:
# 2015 Q1 (January-March)        512
# 2015 Q2 (April-June)           256
# 2015 Q3 (July-September)      1024
# 2015 Q4 (October-December)     256
# 2016 Q1 (January-March)        256
# 2016 Q2 (April-June)           384
# 2016 Q3 (July-September)       384
# 2017 Q1 (January-March)        128
# 2017 Q2 (April-June)           768
# 2017 Q3 (July-September)       128
# 2017 Q4 (October-December)    1280
# 2018 Q1 (January-March)        512
# 2018 Q2 (April-June)           896
# 2020 Q1 (January-March)       3200
# 2020 Q3 (July-September)       428
# Name: Survey wave (calendar quarter), dtype: int64

# %%
# Select rows without missing values in 'Survey_date_dt' column.
L_centr_fnl_2 = L_centr_fnl_0[~L_centr_fnl_0['Survey_date_dt'].isnull()]

# View DataFrame.
L_centr_fnl_2.head()
# Out:
#   Survey wave (calendar quarter) Equivalent financial quarter   Site ID  \
# 0        2014 Q1 (January-March)                   2013-14 Q4  CENCY001
# 1        2014 Q1 (January-March)                   2013-14 Q4  CENCY001
# 2        2014 Q1 (January-March)                   2013-14 Q4  CENCY001
# 3        2014 Q1 (January-March)                   2013-14 Q4  CENCY001
# 4        2014 Q1 (January-March)                   2013-14 Q4  CENCY001
#
#                              Location    Survey date Weather         Time  \
# 0  Millbank (south of Thorney Street)  ven, 24/01/14     Dry  0600 - 0615
# 1  Millbank (south of Thorney Street)  ven, 24/01/14     Dry  0615 - 0630
# 2  Millbank (south of Thorney Street)  ven, 24/01/14     Dry  0630 - 0645
# 3  Millbank (south of Thorney Street)  ven, 24/01/14     Dry  0645 - 0700
# 4  Millbank (south of Thorney Street)  ven, 24/01/14     Dry  0700 - 0715
#
#                         Period   Direction  Start hour  Start minute  \
# 0  Early Morning (06:00-07:00)  Northbound         6.0           0.0
# 1  Early Morning (06:00-07:00)  Northbound         6.0          15.0
# 2  Early Morning (06:00-07:00)  Northbound         6.0          30.0
# 3  Early Morning (06:00-07:00)  Northbound         6.0          45.0
# 4        AM peak (07:00-10:00)  Northbound         7.0           0.0
#
#    Number of private cycles  Number of cycle hire bikes  Total cycles  \
# 0                       0.0                         0.0           0.0
# 1                      15.0                         0.0          15.0
# 2                      35.0                         0.0          35.0
# 3                      59.0                         2.0          61.0
# 4                      73.0                         0.0          73.0
#
#    Survey_wave_year Survey_wave_quater Survey_wave_months Survey_date  \
# 0              2014                 Q1      January-March    24/01/14
# 1              2014                 Q1      January-March    24/01/14
# 2              2014                 Q1      January-March    24/01/14
# 3              2014                 Q1      January-March    24/01/14
# 4              2014                 Q1      January-March    24/01/14
#
#   Survey_date_dt Year-Quarter
# 0     2014-01-24      2014-Q1
# 1     2014-01-24      2014-Q1
# 2     2014-01-24      2014-Q1
# 3     2014-01-24      2014-Q1
# 4     2014-01-24      2014-Q1

# %%
# View number of values in 'Survey_date_dt' column by calendar quarter (excluding missing values).
L_centr_fnl_2['Survey wave (calendar quarter)'].value_counts()
# Out:
# 2019 Q2 (April-June)           26880
# 2019 Q1 (January-March)        26880
# 2018 Q4 (October-December)     26880
# 2018 Q3 (July-September)       26880
# 2019 Q4 (October-December)     26752
# 2019 Q3 (July-September)       26752
# 2021 Q4 (October-December)     26624
# 2017 Q3 (July-September)       26624
# 2021 Q3 (July-September)       26584
# 2020 Q3 (July-September)       26452
# 2018 Q2 (April-June)           25984
# 2014 Q3 (July-September)       25728
# 2014 Q4 (October-December)     25728
# 2016 Q4 (October-December)     25728
# 2014 Q2 (April-June)           25728
# 2017 Q1 (January-March)        25600
# 2017 Q4 (October-December)     25472
# 2015 Q4 (October-December)     25472
# 2015 Q2 (April-June)           25472
# 2014 Q1 (January-March)        25408
# 2016 Q2 (April-June)           25344
# 2016 Q1 (January-March)        25344
# 2018 Q1 (January-March)        25216
# 2016 Q3 (July-September)       25216
# 2015 Q1 (January-March)        25216
# 2017 Q2 (April-June)           24960
# 2015 Q3 (July-September)       24704
# 2020 Q1 (January-March)        23680
# 2021 Q2 (April-June)           12281
# 2021 Q2 (April-June)           12034
# 2021 Q3 (July-September)         128
# Name: Survey wave (calendar quarter), dtype: int64

# %%
# Find first and last date in 'Survey_date_dt' column.
print(L_centr_fnl_0['Survey_date_dt'].min())
print(L_centr_fnl_0['Survey_date_dt'].max())

# View frequency of dates.
L_centr_fnl_0['Survey_date_dt'].value_counts()
# Out:
# 2014-01-20 00:00:00
# 2021-12-30 00:00:00
# 2014-01-30    2690
# 2014-02-03    2330
# 2014-01-31    2207
# 2014-01-29    2185
# 2014-01-28    1874
#               ...
# 2021-12-30      14
# 2018-02-13       8
# 2014-07-07       8
# 2019-07-26       8
# 2019-05-27       2
# Name: Survey_date_dt, Length: 1596, dtype: int64

# %%
# View frequency of location.
L_centr_fnl_0['Location'].value_counts()
# Out:
# Regent Street                    7424
# Charing Cross Road               7424
# Borough High Street              7296
# Southwark Street                 7168
# Lambeth Road                     5504
#                                  ...
# Pakenham Street                  1792
# Tooley Street (east)             1664
# Southwark Bridge Road (south)    1664
# Princess Street                  1664
# Sidmouth Square                  1536
# Name: Location, Length: 205, dtype: int64

# %% [markdown]
# ### Investigate missing dates related to Regent Street location

# %% [markdown]
# #### 2016

# %%
# Select rows with location 'Regent Street' and missing values in 'Survey_date_dt' column.
Rst_0 = L_centr_fnl_0[(L_centr_fnl_0['Location'] == 'Regent Street') & (L_centr_fnl_0['Survey_date_dt'].isnull())]

Rst_0
# Out:
#        Survey wave (calendar quarter) Equivalent financial quarter   Site ID  \
# 282176       2016 Q3 (July-September)                   2016-17 Q2  CENCY701
# 282177       2016 Q3 (July-September)                   2016-17 Q2  CENCY701
# 282178       2016 Q3 (July-September)                   2016-17 Q2  CENCY701
# 282179       2016 Q3 (July-September)                   2016-17 Q2  CENCY701
# 282180       2016 Q3 (July-September)                   2016-17 Q2  CENCY701
# ...                               ...                          ...       ...
# 282299       2016 Q3 (July-September)                   2016-17 Q2  CENCY701
# 282300       2016 Q3 (July-September)                   2016-17 Q2  CENCY701
# 282301       2016 Q3 (July-September)                   2016-17 Q2  CENCY701
# 282302       2016 Q3 (July-September)                   2016-17 Q2  CENCY701
# 282303       2016 Q3 (July-September)                   2016-17 Q2  CENCY701
#
#              Location Survey date Weather         Time  \
# 282176  Regent Street         NaN     NaN  0600 - 0615
# 282177  Regent Street         NaN     NaN  0615 - 0630
# 282178  Regent Street         NaN     NaN  0630 - 0645
# 282179  Regent Street         NaN     NaN  0645 - 0700
# 282180  Regent Street         NaN     NaN  0700 - 0715
# ...               ...         ...     ...          ...
# 282299  Regent Street         NaN     NaN  2045 - 2100
# 282300  Regent Street         NaN     NaN  2100 - 2115
# 282301  Regent Street         NaN     NaN  2115 - 2130
# 282302  Regent Street         NaN     NaN  2130 - 2145
# 282303  Regent Street         NaN     NaN  2145 - 2200
#
#                              Period   Direction  Start hour  Start minute  \
# 282176  Early Morning (06:00-07:00)  Northbound         6.0           0.0
# 282177  Early Morning (06:00-07:00)  Northbound         6.0          15.0
# 282178  Early Morning (06:00-07:00)  Northbound         6.0          30.0
# 282179  Early Morning (06:00-07:00)  Northbound         6.0          45.0
# 282180        AM peak (07:00-10:00)  Northbound         7.0           0.0
# ...                             ...         ...         ...           ...
# 282299        Evening (19:00-22:00)  Southbound        20.0          45.0
# 282300        Evening (19:00-22:00)  Southbound        21.0           0.0
# 282301        Evening (19:00-22:00)  Southbound        21.0          15.0
# 282302        Evening (19:00-22:00)  Southbound        21.0          30.0
# 282303        Evening (19:00-22:00)  Southbound        21.0          45.0
#
#         Number of private cycles  Number of cycle hire bikes  Total cycles  \
# 282176                       7.0                         0.0           7.0
# 282177                       8.0                         0.0           8.0
# 282178                      15.0                         1.0          16.0
# 282179                      13.0                         0.0          13.0
# 282180                      12.0                         0.0          12.0
# ...                          ...                         ...           ...
# 282299                       0.0                         0.0           0.0
# 282300                       0.0                         0.0           0.0
# 282301                       1.0                         0.0           1.0
# 282302                       0.0                         0.0           0.0
# 282303                       0.0                         0.0           0.0
#
#         Survey_wave_year Survey_wave_quater Survey_wave_months Survey_date  \
# 282176              2016                 Q3     July-September         NaN
# 282177              2016                 Q3     July-September         NaN
# 282178              2016                 Q3     July-September         NaN
# 282179              2016                 Q3     July-September         NaN
# 282180              2016                 Q3     July-September         NaN
# ...                  ...                ...                ...         ...
# 282299              2016                 Q3     July-September         NaN
# 282300              2016                 Q3     July-September         NaN
# 282301              2016                 Q3     July-September         NaN
# 282302              2016                 Q3     July-September         NaN
# 282303              2016                 Q3     July-September         NaN
#
#        Survey_date_dt Year-Quarter
# 282176            NaT      2016-Q3
# 282177            NaT      2016-Q3
# 282178            NaT      2016-Q3
# 282179            NaT      2016-Q3
# 282180            NaT      2016-Q3
# ...               ...          ...
# 282299            NaT      2016-Q3
# 282300            NaT      2016-Q3
# 282301            NaT      2016-Q3
# 282302            NaT      2016-Q3
# 282303            NaT      2016-Q3
#
# [128 rows x 20 columns]

# %%
# Check missing values in 'Survey_date_dt' column by calendar quarter related to Regent Street location.
Rst_0['Survey wave (calendar quarter)'].value_counts()

# All missing dates related to Regent Street is within 2016 Q3.
# Out:
# 2016 Q3 (July-September)    128
# Name: Survey wave (calendar quarter), dtype: int64

# %%
# Select rows from the main DataFrame with location 'Regent Street' and 'Survey wave (calendar quarter)' 
# column == 2016 Q3.
Rst_16_Q3 = L_centr_fnl_0[(L_centr_fnl_0['Location'] == 'Regent Street') & 
                          (L_centr_fnl_0['Survey wave (calendar quarter)'] == '2016 Q3 (July-September)')].sort_index()

Rst_16_Q3
# Out:
#        Survey wave (calendar quarter) Equivalent financial quarter   Site ID  \
# 264768       2016 Q3 (July-September)                   2016-17 Q2  CENCY063
# 264769       2016 Q3 (July-September)                   2016-17 Q2  CENCY063
# 264770       2016 Q3 (July-September)                   2016-17 Q2  CENCY063
# 264771       2016 Q3 (July-September)                   2016-17 Q2  CENCY063
# 264772       2016 Q3 (July-September)                   2016-17 Q2  CENCY063
# ...                               ...                          ...       ...
# 282299       2016 Q3 (July-September)                   2016-17 Q2  CENCY701
# 282300       2016 Q3 (July-September)                   2016-17 Q2  CENCY701
# 282301       2016 Q3 (July-September)                   2016-17 Q2  CENCY701
# 282302       2016 Q3 (July-September)                   2016-17 Q2  CENCY701
# 282303       2016 Q3 (July-September)                   2016-17 Q2  CENCY701
#
#              Location    Survey date Weather         Time  \
# 264768  Regent Street  ven, 09/09/16     Dry  0600 - 0615
# 264769  Regent Street  ven, 09/09/16     Dry  0615 - 0630
# 264770  Regent Street  ven, 09/09/16     Dry  0630 - 0645
# 264771  Regent Street  ven, 09/09/16     Dry  0645 - 0700
# 264772  Regent Street  ven, 09/09/16     Dry  0700 - 0715
# ...               ...            ...     ...          ...
# 282299  Regent Street            NaN     NaN  2045 - 2100
# 282300  Regent Street            NaN     NaN  2100 - 2115
# 282301  Regent Street            NaN     NaN  2115 - 2130
# 282302  Regent Street            NaN     NaN  2130 - 2145
# 282303  Regent Street            NaN     NaN  2145 - 2200
#
#                              Period   Direction  Start hour  Start minute  \
# 264768  Early Morning (06:00-07:00)  Northbound         6.0           0.0
# 264769  Early Morning (06:00-07:00)  Northbound         6.0          15.0
# 264770  Early Morning (06:00-07:00)  Northbound         6.0          30.0
# 264771  Early Morning (06:00-07:00)  Northbound         6.0          45.0
# 264772        AM peak (07:00-10:00)  Northbound         7.0           0.0
# ...                             ...         ...         ...           ...
# 282299        Evening (19:00-22:00)  Southbound        20.0          45.0
# 282300        Evening (19:00-22:00)  Southbound        21.0           0.0
# 282301        Evening (19:00-22:00)  Southbound        21.0          15.0
# 282302        Evening (19:00-22:00)  Southbound        21.0          30.0
# 282303        Evening (19:00-22:00)  Southbound        21.0          45.0
#
#         Number of private cycles  Number of cycle hire bikes  Total cycles  \
# 264768                       1.0                         0.0           1.0
# 264769                       2.0                         0.0           2.0
# 264770                       9.0                         1.0          10.0
# 264771                      14.0                         1.0          15.0
# 264772                      17.0                         3.0          20.0
# ...                          ...                         ...           ...
# 282299                       0.0                         0.0           0.0
# 282300                       0.0                         0.0           0.0
# 282301                       1.0                         0.0           1.0
# 282302                       0.0                         0.0           0.0
# 282303                       0.0                         0.0           0.0
#
#         Survey_wave_year Survey_wave_quater Survey_wave_months Survey_date  \
# 264768              2016                 Q3     July-September    09/09/16
# 264769              2016                 Q3     July-September    09/09/16
# 264770              2016                 Q3     July-September    09/09/16
# 264771              2016                 Q3     July-September    09/09/16
# 264772              2016                 Q3     July-September    09/09/16
# ...                  ...                ...                ...         ...
# 282299              2016                 Q3     July-September         NaN
# 282300              2016                 Q3     July-September         NaN
# 282301              2016                 Q3     July-September         NaN
# 282302              2016                 Q3     July-September         NaN
# 282303              2016                 Q3     July-September         NaN
#
#        Survey_date_dt Year-Quarter
# 264768     2016-09-09      2016-Q3
# 264769     2016-09-09      2016-Q3
# 264770     2016-09-09      2016-Q3
# 264771     2016-09-09      2016-Q3
# 264772     2016-09-09      2016-Q3
# ...               ...          ...
# 282299            NaT      2016-Q3
# 282300            NaT      2016-Q3
# 282301            NaT      2016-Q3
# 282302            NaT      2016-Q3
# 282303            NaT      2016-Q3
#
# [256 rows x 20 columns]

# %%
# Check dates related to the flollowing rows after 282303 and 2016 Q3.
L_centr_fnl_0.loc[(L_centr_fnl_0.index > 282303) & 
                  (L_centr_fnl_0['Survey wave (calendar quarter)'] == '2016 Q3 (July-September)')]
# Out:
#        Survey wave (calendar quarter) Equivalent financial quarter   Site ID  \
# 282304       2016 Q3 (July-September)                   2016-17 Q2  CENCY702
# 282305       2016 Q3 (July-September)                   2016-17 Q2  CENCY702
# 282306       2016 Q3 (July-September)                   2016-17 Q2  CENCY702
# 282307       2016 Q3 (July-September)                   2016-17 Q2  CENCY702
# 282308       2016 Q3 (July-September)                   2016-17 Q2  CENCY702
# ...                               ...                          ...       ...
# 282427       2016 Q3 (July-September)                   2016-17 Q2  CENCY702
# 282428       2016 Q3 (July-September)                   2016-17 Q2  CENCY702
# 282429       2016 Q3 (July-September)                   2016-17 Q2  CENCY702
# 282430       2016 Q3 (July-September)                   2016-17 Q2  CENCY702
# 282431       2016 Q3 (July-September)                   2016-17 Q2  CENCY702
#
#          Location    Survey date Weather         Time  \
# 282304  Haymarket  lun, 19/09/16     Dry  0600 - 0615
# 282305  Haymarket  lun, 19/09/16     Dry  0615 - 0630
# 282306  Haymarket  lun, 19/09/16     Dry  0630 - 0645
# 282307  Haymarket  lun, 19/09/16     Dry  0645 - 0700
# 282308  Haymarket  lun, 19/09/16     Dry  0700 - 0715
# ...           ...            ...     ...          ...
# 282427  Haymarket  mar, 13/09/16     Dry  2045 - 2100
# 282428  Haymarket  mar, 13/09/16     Dry  2100 - 2115
# 282429  Haymarket  mar, 13/09/16     Dry  2115 - 2130
# 282430  Haymarket  mar, 13/09/16     Dry  2130 - 2145
# 282431  Haymarket  mar, 13/09/16     Dry  2145 - 2200
#
#                              Period   Direction  Start hour  Start minute  \
# 282304  Early Morning (06:00-07:00)  Northbound         6.0           0.0
# 282305  Early Morning (06:00-07:00)  Northbound         6.0          15.0
# 282306  Early Morning (06:00-07:00)  Northbound         6.0          30.0
# 282307  Early Morning (06:00-07:00)  Northbound         6.0          45.0
# 282308        AM peak (07:00-10:00)  Northbound         7.0           0.0
# ...                             ...         ...         ...           ...
# 282427        Evening (19:00-22:00)  Southbound        20.0          45.0
# 282428        Evening (19:00-22:00)  Southbound        21.0           0.0
# 282429        Evening (19:00-22:00)  Southbound        21.0          15.0
# 282430        Evening (19:00-22:00)  Southbound        21.0          30.0
# 282431        Evening (19:00-22:00)  Southbound        21.0          45.0
#
#         Number of private cycles  Number of cycle hire bikes  Total cycles  \
# 282304                       0.0                         0.0           0.0
# 282305                       0.0                         0.0           0.0
# 282306                       0.0                         0.0           0.0
# 282307                       1.0                         0.0           1.0
# 282308                       2.0                         0.0           2.0
# ...                          ...                         ...           ...
# 282427                      28.0                         3.0          31.0
# 282428                      26.0                         1.0          27.0
# 282429                      23.0                         1.0          24.0
# 282430                      26.0                         0.0          26.0
# 282431                      19.0                         1.0          20.0
#
#         Survey_wave_year Survey_wave_quater Survey_wave_months Survey_date  \
# 282304              2016                 Q3     July-September    19/09/16
# 282305              2016                 Q3     July-September    19/09/16
# 282306              2016                 Q3     July-September    19/09/16
# 282307              2016                 Q3     July-September    19/09/16
# 282308              2016                 Q3     July-September    19/09/16
# ...                  ...                ...                ...         ...
# 282427              2016                 Q3     July-September    13/09/16
# 282428              2016                 Q3     July-September    13/09/16
# 282429              2016                 Q3     July-September    13/09/16
# 282430              2016                 Q3     July-September    13/09/16
# 282431              2016                 Q3     July-September    13/09/16
#
#        Survey_date_dt Year-Quarter
# 282304     2016-09-19      2016-Q3
# 282305     2016-09-19      2016-Q3
# 282306     2016-09-19      2016-Q3
# 282307     2016-09-19      2016-Q3
# 282308     2016-09-19      2016-Q3
# ...               ...          ...
# 282427     2016-09-13      2016-Q3
# 282428     2016-09-13      2016-Q3
# 282429     2016-09-13      2016-Q3
# 282430     2016-09-13      2016-Q3
# 282431     2016-09-13      2016-Q3
#
# [128 rows x 20 columns]

# %%
# View frequency of dates in 'Survey_date_dt' column.
Rst_16_Q3['Survey_date_dt'].value_counts()
# Out:
# 2016-09-09    64
# 2016-09-08    64
# Name: Survey_date_dt, dtype: int64

# %%
# Check dates related to CENCY063 site ID in 2016 Q1.
Rst_16_Q3.loc[Rst_16_Q3['Site ID'] == 'CENCY063']['Survey_date_dt'].value_counts(sort=False)
# Out:
# 2016-09-09    64
# 2016-09-08    64
# Name: Survey_date_dt, dtype: int64

# %%
# View frequency of time slots in 'Time' column.
Rst_16_Q3['Time'].value_counts()
# Out:
# 0600 - 0615    4
# 0615 - 0630    4
# 1430 - 1445    4
# 1445 - 1500    4
# 1500 - 1515    4
#               ..
# 1230 - 1245    4
# 1245 - 1300    4
# 1300 - 1315    4
# 1315 - 1330    4
# 2145 - 2200    4
# Name: Time, Length: 64, dtype: int64

# %%
# View frequency of sites in 'Site ID' column.
Rst_16_Q3['Site ID'].value_counts()
# Out:
# CENCY063    128
# CENCY701    128
# Name: Site ID, dtype: int64

# %%
# Check missing values in 2016 Q3 for CENCY063 site ID.
Rst_16_Q3.loc[(Rst_16_Q3['Site ID'] == 'CENCY063') & (Rst_16_Q3['Survey_date_dt'].isnull())]
# Out:
# Empty DataFrame
# Columns: [Survey wave (calendar quarter), Equivalent financial quarter, Site ID, Location, Survey date, Weather, Time, Period, Direction, Start hour, Start minute, Number of private cycles, Number of cycle hire bikes, Total cycles, Survey_wave_year, Survey_wave_quater, Survey_wave_months, Survey_date, Survey_date_dt, Year-Quarter]
# Index: []

# %%
# Check missing values in 2016 Q3 for CENCY701 site ID.
Rst_16_Q3.loc[(Rst_16_Q3['Site ID'] == 'CENCY701') & (Rst_16_Q3['Survey_date_dt'].isnull())]
# Out:
#        Survey wave (calendar quarter) Equivalent financial quarter   Site ID  \
# 282176       2016 Q3 (July-September)                   2016-17 Q2  CENCY701
# 282177       2016 Q3 (July-September)                   2016-17 Q2  CENCY701
# 282178       2016 Q3 (July-September)                   2016-17 Q2  CENCY701
# 282179       2016 Q3 (July-September)                   2016-17 Q2  CENCY701
# 282180       2016 Q3 (July-September)                   2016-17 Q2  CENCY701
# ...                               ...                          ...       ...
# 282299       2016 Q3 (July-September)                   2016-17 Q2  CENCY701
# 282300       2016 Q3 (July-September)                   2016-17 Q2  CENCY701
# 282301       2016 Q3 (July-September)                   2016-17 Q2  CENCY701
# 282302       2016 Q3 (July-September)                   2016-17 Q2  CENCY701
# 282303       2016 Q3 (July-September)                   2016-17 Q2  CENCY701
#
#              Location Survey date Weather         Time  \
# 282176  Regent Street         NaN     NaN  0600 - 0615
# 282177  Regent Street         NaN     NaN  0615 - 0630
# 282178  Regent Street         NaN     NaN  0630 - 0645
# 282179  Regent Street         NaN     NaN  0645 - 0700
# 282180  Regent Street         NaN     NaN  0700 - 0715
# ...               ...         ...     ...          ...
# 282299  Regent Street         NaN     NaN  2045 - 2100
# 282300  Regent Street         NaN     NaN  2100 - 2115
# 282301  Regent Street         NaN     NaN  2115 - 2130
# 282302  Regent Street         NaN     NaN  2130 - 2145
# 282303  Regent Street         NaN     NaN  2145 - 2200
#
#                              Period   Direction  Start hour  Start minute  \
# 282176  Early Morning (06:00-07:00)  Northbound         6.0           0.0
# 282177  Early Morning (06:00-07:00)  Northbound         6.0          15.0
# 282178  Early Morning (06:00-07:00)  Northbound         6.0          30.0
# 282179  Early Morning (06:00-07:00)  Northbound         6.0          45.0
# 282180        AM peak (07:00-10:00)  Northbound         7.0           0.0
# ...                             ...         ...         ...           ...
# 282299        Evening (19:00-22:00)  Southbound        20.0          45.0
# 282300        Evening (19:00-22:00)  Southbound        21.0           0.0
# 282301        Evening (19:00-22:00)  Southbound        21.0          15.0
# 282302        Evening (19:00-22:00)  Southbound        21.0          30.0
# 282303        Evening (19:00-22:00)  Southbound        21.0          45.0
#
#         Number of private cycles  Number of cycle hire bikes  Total cycles  \
# 282176                       7.0                         0.0           7.0
# 282177                       8.0                         0.0           8.0
# 282178                      15.0                         1.0          16.0
# 282179                      13.0                         0.0          13.0
# 282180                      12.0                         0.0          12.0
# ...                          ...                         ...           ...
# 282299                       0.0                         0.0           0.0
# 282300                       0.0                         0.0           0.0
# 282301                       1.0                         0.0           1.0
# 282302                       0.0                         0.0           0.0
# 282303                       0.0                         0.0           0.0
#
#         Survey_wave_year Survey_wave_quater Survey_wave_months Survey_date  \
# 282176              2016                 Q3     July-September         NaN
# 282177              2016                 Q3     July-September         NaN
# 282178              2016                 Q3     July-September         NaN
# 282179              2016                 Q3     July-September         NaN
# 282180              2016                 Q3     July-September         NaN
# ...                  ...                ...                ...         ...
# 282299              2016                 Q3     July-September         NaN
# 282300              2016                 Q3     July-September         NaN
# 282301              2016                 Q3     July-September         NaN
# 282302              2016                 Q3     July-September         NaN
# 282303              2016                 Q3     July-September         NaN
#
#        Survey_date_dt Year-Quarter
# 282176            NaT      2016-Q3
# 282177            NaT      2016-Q3
# 282178            NaT      2016-Q3
# 282179            NaT      2016-Q3
# 282180            NaT      2016-Q3
# ...               ...          ...
# 282299            NaT      2016-Q3
# 282300            NaT      2016-Q3
# 282301            NaT      2016-Q3
# 282302            NaT      2016-Q3
# 282303            NaT      2016-Q3
#
# [128 rows x 20 columns]

# %%
# Check how many site IDs are asigned to Regent Street location.
Rst = L_centr_fnl_0.loc[L_centr_fnl_0['Location'] == 'Regent Street']
print(Rst['Site ID'].value_counts())

# View DataFrame.
Rst.head()
# Out:
# CENCY063    3712
# CENCY701    3712
# Name: Site ID, dtype: int64
#      Survey wave (calendar quarter) Equivalent financial quarter   Site ID  \
# 7936        2014 Q1 (January-March)                   2013-14 Q4  CENCY063
# 7937        2014 Q1 (January-March)                   2013-14 Q4  CENCY063
# 7938        2014 Q1 (January-March)                   2013-14 Q4  CENCY063
# 7939        2014 Q1 (January-March)                   2013-14 Q4  CENCY063
# 7940        2014 Q1 (January-March)                   2013-14 Q4  CENCY063
#
#            Location    Survey date Weather         Time  \
# 7936  Regent Street  mar, 28/01/14     Dry  0600 - 0615
# 7937  Regent Street  mar, 28/01/14     Dry  0615 - 0630
# 7938  Regent Street  mar, 28/01/14     Dry  0630 - 0645
# 7939  Regent Street  mar, 28/01/14     Dry  0645 - 0700
# 7940  Regent Street  mar, 28/01/14     Dry  0700 - 0715
#
#                            Period   Direction  Start hour  Start minute  \
# 7936  Early Morning (06:00-07:00)  Northbound         6.0           0.0
# 7937  Early Morning (06:00-07:00)  Northbound         6.0          15.0
# 7938  Early Morning (06:00-07:00)  Northbound         6.0          30.0
# 7939  Early Morning (06:00-07:00)  Northbound         6.0          45.0
# 7940        AM peak (07:00-10:00)  Northbound         7.0           0.0
#
#       Number of private cycles  Number of cycle hire bikes  Total cycles  \
# 7936                       1.0                         0.0           1.0
# 7937                       2.0                         0.0           2.0
# 7938                       8.0                         0.0           8.0
# 7939                       5.0                         0.0           5.0
# 7940                       5.0                         0.0           5.0
#
#       Survey_wave_year Survey_wave_quater Survey_wave_months Survey_date  \
# 7936              2014                 Q1      January-March    28/01/14
# 7937              2014                 Q1      January-March    28/01/14
# 7938              2014                 Q1      January-March    28/01/14
# 7939              2014                 Q1      January-March    28/01/14
# 7940              2014                 Q1      January-March    28/01/14
#
#      Survey_date_dt Year-Quarter
# 7936     2014-01-28      2014-Q1
# 7937     2014-01-28      2014-Q1
# 7938     2014-01-28      2014-Q1
# 7939     2014-01-28      2014-Q1
# 7940     2014-01-28      2014-Q1

# %%
# Select rows related to 2016 Q1.
Rst_16_Q1 = Rst.loc[Rst['Survey wave (calendar quarter)'] == '2016 Q1 (January-March)'].sort_index() 

# View DataFrame.
Rst_16_Q1
# Out:
#        Survey wave (calendar quarter) Equivalent financial quarter   Site ID  \
# 213440        2016 Q1 (January-March)                   2015-16 Q4  CENCY063
# 213441        2016 Q1 (January-March)                   2015-16 Q4  CENCY063
# 213442        2016 Q1 (January-March)                   2015-16 Q4  CENCY063
# 213443        2016 Q1 (January-March)                   2015-16 Q4  CENCY063
# 213444        2016 Q1 (January-March)                   2015-16 Q4  CENCY063
# ...                               ...                          ...       ...
# 230971        2016 Q1 (January-March)                   2015-16 Q4  CENCY701
# 230972        2016 Q1 (January-March)                   2015-16 Q4  CENCY701
# 230973        2016 Q1 (January-March)                   2015-16 Q4  CENCY701
# 230974        2016 Q1 (January-March)                   2015-16 Q4  CENCY701
# 230975        2016 Q1 (January-March)                   2015-16 Q4  CENCY701
#
#              Location    Survey date Weather         Time  \
# 213440  Regent Street  mar, 22/03/16     Dry  0600 - 0615
# 213441  Regent Street  mar, 22/03/16     Dry  0615 - 0630
# 213442  Regent Street  mar, 22/03/16     Dry  0630 - 0645
# 213443  Regent Street  mar, 22/03/16     Dry  0645 - 0700
# 213444  Regent Street  mar, 22/03/16     Dry  0700 - 0715
# ...               ...            ...     ...          ...
# 230971  Regent Street  mer, 10/02/16     Dry  2045 - 2100
# 230972  Regent Street  mer, 10/02/16     Dry  2100 - 2115
# 230973  Regent Street  mer, 10/02/16     Dry  2115 - 2130
# 230974  Regent Street  mer, 10/02/16     Dry  2130 - 2145
# 230975  Regent Street  mer, 10/02/16     Dry  2145 - 2200
#
#                              Period   Direction  Start hour  Start minute  \
# 213440  Early Morning (06:00-07:00)  Northbound         6.0           0.0
# 213441  Early Morning (06:00-07:00)  Northbound         6.0          15.0
# 213442  Early Morning (06:00-07:00)  Northbound         6.0          30.0
# 213443  Early Morning (06:00-07:00)  Northbound         6.0          45.0
# 213444        AM peak (07:00-10:00)  Northbound         7.0           0.0
# ...                             ...         ...         ...           ...
# 230971        Evening (19:00-22:00)  Southbound        20.0          45.0
# 230972        Evening (19:00-22:00)  Southbound        21.0           0.0
# 230973        Evening (19:00-22:00)  Southbound        21.0          15.0
# 230974        Evening (19:00-22:00)  Southbound        21.0          30.0
# 230975        Evening (19:00-22:00)  Southbound        21.0          45.0
#
#         Number of private cycles  Number of cycle hire bikes  Total cycles  \
# 213440                       2.0                         0.0           2.0
# 213441                       9.0                         0.0           9.0
# 213442                      11.0                         0.0          11.0
# 213443                      20.0                         0.0          20.0
# 213444                      15.0                         0.0          15.0
# ...                          ...                         ...           ...
# 230971                       0.0                         2.0           2.0
# 230972                       0.0                         0.0           0.0
# 230973                       1.0                         0.0           1.0
# 230974                       2.0                         0.0           2.0
# 230975                       0.0                         0.0           0.0
#
#         Survey_wave_year Survey_wave_quater Survey_wave_months Survey_date  \
# 213440              2016                 Q1      January-March    22/03/16
# 213441              2016                 Q1      January-March    22/03/16
# 213442              2016                 Q1      January-March    22/03/16
# 213443              2016                 Q1      January-March    22/03/16
# 213444              2016                 Q1      January-March    22/03/16
# ...                  ...                ...                ...         ...
# 230971              2016                 Q1      January-March    10/02/16
# 230972              2016                 Q1      January-March    10/02/16
# 230973              2016                 Q1      January-March    10/02/16
# 230974              2016                 Q1      January-March    10/02/16
# 230975              2016                 Q1      January-March    10/02/16
#
#        Survey_date_dt Year-Quarter
# 213440     2016-03-22      2016-Q1
# 213441     2016-03-22      2016-Q1
# 213442     2016-03-22      2016-Q1
# 213443     2016-03-22      2016-Q1
# 213444     2016-03-22      2016-Q1
# ...               ...          ...
# 230971     2016-02-10      2016-Q1
# 230972     2016-02-10      2016-Q1
# 230973     2016-02-10      2016-Q1
# 230974     2016-02-10      2016-Q1
# 230975     2016-02-10      2016-Q1
#
# [256 rows x 20 columns]

# %%
# View frequency of dates in 'Survey_date_dt' column.
Rst_16_Q1['Survey_date_dt'].value_counts()
# Out:
# 2016-03-22    64
# 2016-03-16    64
# 2016-02-09    64
# 2016-02-10    64
# Name: Survey_date_dt, dtype: int64

# %%
# View frequency of sites in 'Site ID' column.
Rst_16_Q1['Site ID'].value_counts()
# Out:
# CENCY063    128
# CENCY701    128
# Name: Site ID, dtype: int64

# %%
# View frequency of time slots in 'Time' column.
Rst_16_Q1['Time'].value_counts()
# Out:
# 0600 - 0615    4
# 0615 - 0630    4
# 1430 - 1445    4
# 1445 - 1500    4
# 1500 - 1515    4
#               ..
# 1230 - 1245    4
# 1245 - 1300    4
# 1300 - 1315    4
# 1315 - 1330    4
# 2145 - 2200    4
# Name: Time, Length: 64, dtype: int64

# %%
# Check dates related to CENCY063 site ID in 2016 Q1.
Rst_16_Q1.loc[Rst_16_Q1['Site ID'] == 'CENCY063']['Survey_date_dt'].value_counts(sort=False)
# Out:
# 2016-03-22    64
# 2016-03-16    64
# Name: Survey_date_dt, dtype: int64

# %%
# Select rows related to 2016 Q2.
Rst_16_Q2 = Rst.loc[Rst['Survey wave (calendar quarter)'] == '2016 Q2 (April-June)'] 

# View DataFrame.
Rst_16_Q2
# Out:
#        Survey wave (calendar quarter) Equivalent financial quarter   Site ID  \
# 239040           2016 Q2 (April-June)                   2016-17 Q1  CENCY063
# 239041           2016 Q2 (April-June)                   2016-17 Q1  CENCY063
# 239042           2016 Q2 (April-June)                   2016-17 Q1  CENCY063
# 239043           2016 Q2 (April-June)                   2016-17 Q1  CENCY063
# 239044           2016 Q2 (April-June)                   2016-17 Q1  CENCY063
# ...                               ...                          ...       ...
# 256699           2016 Q2 (April-June)                   2016-17 Q1  CENCY701
# 256700           2016 Q2 (April-June)                   2016-17 Q1  CENCY701
# 256701           2016 Q2 (April-June)                   2016-17 Q1  CENCY701
# 256702           2016 Q2 (April-June)                   2016-17 Q1  CENCY701
# 256703           2016 Q2 (April-June)                   2016-17 Q1  CENCY701
#
#              Location    Survey date Weather         Time  \
# 239040  Regent Street  mer, 22/06/16     Dry  0600 - 0615
# 239041  Regent Street  mer, 22/06/16     Dry  0615 - 0630
# 239042  Regent Street  mer, 22/06/16     Dry  0630 - 0645
# 239043  Regent Street  mer, 22/06/16     Dry  0645 - 0700
# 239044  Regent Street  mer, 22/06/16     Dry  0700 - 0715
# ...               ...            ...     ...          ...
# 256699  Regent Street  ven, 29/04/16     Dry  2045 - 2100
# 256700  Regent Street  ven, 29/04/16     Dry  2100 - 2115
# 256701  Regent Street  ven, 29/04/16     Dry  2115 - 2130
# 256702  Regent Street  ven, 29/04/16     Dry  2130 - 2145
# 256703  Regent Street  ven, 29/04/16     Dry  2145 - 2200
#
#                              Period   Direction  Start hour  Start minute  \
# 239040  Early Morning (06:00-07:00)  Northbound         6.0           0.0
# 239041  Early Morning (06:00-07:00)  Northbound         6.0          15.0
# 239042  Early Morning (06:00-07:00)  Northbound         6.0          30.0
# 239043  Early Morning (06:00-07:00)  Northbound         6.0          45.0
# 239044        AM peak (07:00-10:00)  Northbound         7.0           0.0
# ...                             ...         ...         ...           ...
# 256699        Evening (19:00-22:00)  Southbound        20.0          45.0
# 256700        Evening (19:00-22:00)  Southbound        21.0           0.0
# 256701        Evening (19:00-22:00)  Southbound        21.0          15.0
# 256702        Evening (19:00-22:00)  Southbound        21.0          30.0
# 256703        Evening (19:00-22:00)  Southbound        21.0          45.0
#
#         Number of private cycles  Number of cycle hire bikes  Total cycles  \
# 239040                       5.0                         0.0           5.0
# 239041                       4.0                         0.0           4.0
# 239042                      10.0                         1.0          11.0
# 239043                      14.0                         0.0          14.0
# 239044                      19.0                         0.0          19.0
# ...                          ...                         ...           ...
# 256699                       0.0                         0.0           0.0
# 256700                       0.0                         0.0           0.0
# 256701                       0.0                         0.0           0.0
# 256702                       0.0                         0.0           0.0
# 256703                       0.0                         0.0           0.0
#
#         Survey_wave_year Survey_wave_quater Survey_wave_months Survey_date  \
# 239040              2016                 Q2         April-June    22/06/16
# 239041              2016                 Q2         April-June    22/06/16
# 239042              2016                 Q2         April-June    22/06/16
# 239043              2016                 Q2         April-June    22/06/16
# 239044              2016                 Q2         April-June    22/06/16
# ...                  ...                ...                ...         ...
# 256699              2016                 Q2         April-June    29/04/16
# 256700              2016                 Q2         April-June    29/04/16
# 256701              2016                 Q2         April-June    29/04/16
# 256702              2016                 Q2         April-June    29/04/16
# 256703              2016                 Q2         April-June    29/04/16
#
#        Survey_date_dt Year-Quarter
# 239040     2016-06-22      2016-Q2
# 239041     2016-06-22      2016-Q2
# 239042     2016-06-22      2016-Q2
# 239043     2016-06-22      2016-Q2
# 239044     2016-06-22      2016-Q2
# ...               ...          ...
# 256699     2016-04-29      2016-Q2
# 256700     2016-04-29      2016-Q2
# 256701     2016-04-29      2016-Q2
# 256702     2016-04-29      2016-Q2
# 256703     2016-04-29      2016-Q2
#
# [256 rows x 20 columns]

# %%
# View frequency of dates in 'Survey_date_dt' column.
Rst_16_Q2['Survey_date_dt'].value_counts()
# Out:
# 2016-06-22    64
# 2016-06-28    64
# 2016-04-28    64
# 2016-04-29    64
# Name: Survey_date_dt, dtype: int64

# %%
# View frequency of sites in 'Site ID' column.
Rst_16_Q2['Site ID'].value_counts()
# Out:
# CENCY063    128
# CENCY701    128
# Name: Site ID, dtype: int64

# %%
# Check dates related to CENCY063 site ID in 2016 Q2.
Rst_16_Q2.loc[Rst_16_Q2['Site ID'] == 'CENCY063']['Survey_date_dt'].value_counts(sort=False)
# Out:
# 2016-06-22    64
# 2016-06-28    64
# Name: Survey_date_dt, dtype: int64

# %%
# View frequency of time slots in 'Time' column.
Rst_16_Q2['Time'].value_counts()
# Out:
# 0600 - 0615    4
# 0615 - 0630    4
# 1430 - 1445    4
# 1445 - 1500    4
# 1500 - 1515    4
#               ..
# 1230 - 1245    4
# 1245 - 1300    4
# 1300 - 1315    4
# 1315 - 1330    4
# 2145 - 2200    4
# Name: Time, Length: 64, dtype: int64

# %%
# Select rows related to 2016 Q4.
Rst_16_Q4 = Rst.loc[Rst['Survey wave (calendar quarter)'] == '2016 Q4 (October-December)'].sort_index() 

# View DataFrame.
Rst_16_Q4
# Out:
#        Survey wave (calendar quarter) Equivalent financial quarter   Site ID  \
# 290368     2016 Q4 (October-December)                   2016-17 Q3  CENCY063
# 290369     2016 Q4 (October-December)                   2016-17 Q3  CENCY063
# 290370     2016 Q4 (October-December)                   2016-17 Q3  CENCY063
# 290371     2016 Q4 (October-December)                   2016-17 Q3  CENCY063
# 290372     2016 Q4 (October-December)                   2016-17 Q3  CENCY063
# ...                               ...                          ...       ...
# 308027     2016 Q4 (October-December)                   2016-17 Q3  CENCY701
# 308028     2016 Q4 (October-December)                   2016-17 Q3  CENCY701
# 308029     2016 Q4 (October-December)                   2016-17 Q3  CENCY701
# 308030     2016 Q4 (October-December)                   2016-17 Q3  CENCY701
# 308031     2016 Q4 (October-December)                   2016-17 Q3  CENCY701
#
#              Location    Survey date Weather         Time  \
# 290368  Regent Street  ven, 16/12/16     Dry  0600 - 0615
# 290369  Regent Street  ven, 16/12/16     Dry  0615 - 0630
# 290370  Regent Street  ven, 16/12/16     Dry  0630 - 0645
# 290371  Regent Street  ven, 16/12/16     Dry  0645 - 0700
# 290372  Regent Street  ven, 16/12/16     Dry  0700 - 0715
# ...               ...            ...     ...          ...
# 308027  Regent Street  jeu, 17/11/16     Dry  2045 - 2100
# 308028  Regent Street  jeu, 17/11/16     Dry  2100 - 2115
# 308029  Regent Street  jeu, 17/11/16     Dry  2115 - 2130
# 308030  Regent Street  jeu, 17/11/16     Dry  2130 - 2145
# 308031  Regent Street  jeu, 17/11/16     Dry  2145 - 2200
#
#                              Period   Direction  Start hour  Start minute  \
# 290368  Early Morning (06:00-07:00)  Northbound         6.0           0.0
# 290369  Early Morning (06:00-07:00)  Northbound         6.0          15.0
# 290370  Early Morning (06:00-07:00)  Northbound         6.0          30.0
# 290371  Early Morning (06:00-07:00)  Northbound         6.0          45.0
# 290372        AM peak (07:00-10:00)  Northbound         7.0           0.0
# ...                             ...         ...         ...           ...
# 308027        Evening (19:00-22:00)  Southbound        20.0          45.0
# 308028        Evening (19:00-22:00)  Southbound        21.0           0.0
# 308029        Evening (19:00-22:00)  Southbound        21.0          15.0
# 308030        Evening (19:00-22:00)  Southbound        21.0          30.0
# 308031        Evening (19:00-22:00)  Southbound        21.0          45.0
#
#         Number of private cycles  Number of cycle hire bikes  Total cycles  \
# 290368                       0.0                         0.0           0.0
# 290369                       0.0                         0.0           0.0
# 290370                       7.0                         0.0           7.0
# 290371                      12.0                         0.0          12.0
# 290372                       3.0                         0.0           3.0
# ...                          ...                         ...           ...
# 308027                       0.0                         0.0           0.0
# 308028                       0.0                         0.0           0.0
# 308029                       1.0                         0.0           1.0
# 308030                       0.0                         0.0           0.0
# 308031                       0.0                         0.0           0.0
#
#         Survey_wave_year Survey_wave_quater Survey_wave_months Survey_date  \
# 290368              2016                 Q4   October-December    16/12/16
# 290369              2016                 Q4   October-December    16/12/16
# 290370              2016                 Q4   October-December    16/12/16
# 290371              2016                 Q4   October-December    16/12/16
# 290372              2016                 Q4   October-December    16/12/16
# ...                  ...                ...                ...         ...
# 308027              2016                 Q4   October-December    17/11/16
# 308028              2016                 Q4   October-December    17/11/16
# 308029              2016                 Q4   October-December    17/11/16
# 308030              2016                 Q4   October-December    17/11/16
# 308031              2016                 Q4   October-December    17/11/16
#
#        Survey_date_dt Year-Quarter
# 290368     2016-12-16      2016-Q4
# 290369     2016-12-16      2016-Q4
# 290370     2016-12-16      2016-Q4
# 290371     2016-12-16      2016-Q4
# 290372     2016-12-16      2016-Q4
# ...               ...          ...
# 308027     2016-11-17      2016-Q4
# 308028     2016-11-17      2016-Q4
# 308029     2016-11-17      2016-Q4
# 308030     2016-11-17      2016-Q4
# 308031     2016-11-17      2016-Q4
#
# [256 rows x 20 columns]

# %%
# View frequency of dates in 'Survey_date_dt' column.
Rst_16_Q4['Survey_date_dt'].value_counts(sort=False)
# Out:
# 2016-12-16    74
# 2016-12-12    16
# 2016-12-15    38
# 2016-11-18    12
# 2016-11-22    24
# 2016-11-15    36
# 2016-11-16    10
# 2016-11-17    32
# 2016-11-21    14
# Name: Survey_date_dt, dtype: int64

# %%
# See dates order.
a = Rst_16_Q4['Survey_date_dt'].drop_duplicates()
a

# No consistency of date order (by index), e.g. 2016-11-21 is in between of rows related to data for 2016-11-17. 
# BUT within Qs months are in descending order.
# Out:
# 290368   2016-12-16
# 290381   2016-12-12
# 290389   2016-12-15
# 307904   2016-11-18
# 307910   2016-11-22
# 307922   2016-11-15
# 307930   2016-11-16
# 307935   2016-11-17
# 307944   2016-11-21
# Name: Survey_date_dt, dtype: datetime64[ns]

# %%
# View frequency of sites in 'Site ID' column.
Rst_16_Q4['Site ID'].value_counts()
# Out:
# CENCY063    128
# CENCY701    128
# Name: Site ID, dtype: int64

# %%
# Check dates related to CENCY063 site ID in 2016 Q4.
Rst_16_Q4.loc[Rst_16_Q4['Site ID'] == 'CENCY063']['Survey_date_dt'].value_counts(sort=False)
# Out:
# 2016-12-16    74
# 2016-12-12    16
# 2016-12-15    38
# Name: Survey_date_dt, dtype: int64

# %%
# View frequency of time slots in 'Time' column.
Rst_16_Q4['Time'].value_counts()
# Out:
# 0600 - 0615    4
# 0615 - 0630    4
# 1430 - 1445    4
# 1445 - 1500    4
# 1500 - 1515    4
#               ..
# 1230 - 1245    4
# 1245 - 1300    4
# 1300 - 1315    4
# 1315 - 1330    4
# 2145 - 2200    4
# Name: Time, Length: 64, dtype: int64

# %% [markdown]
# #### 2015

# %%
# Select rows from the main DataFrame with location 'Regent Street' and 'Survey wave (calendar quarter)' 
# column == 2015 Q3.
Rst_15_Q3 = L_centr_fnl_0[(L_centr_fnl_0['Location'] == 'Regent Street') & 
                          (L_centr_fnl_0['Survey wave (calendar quarter)'] == '2015 Q3 (July-September)')].sort_index()

Rst_15_Q3
# Out:
#        Survey wave (calendar quarter) Equivalent financial quarter   Site ID  \
# 161984       2015 Q3 (July-September)                   2015-16 Q2  CENCY063
# 161985       2015 Q3 (July-September)                   2015-16 Q2  CENCY063
# 161986       2015 Q3 (July-September)                   2015-16 Q2  CENCY063
# 161987       2015 Q3 (July-September)                   2015-16 Q2  CENCY063
# 161988       2015 Q3 (July-September)                   2015-16 Q2  CENCY063
# ...                               ...                          ...       ...
# 179643       2015 Q3 (July-September)                   2015-16 Q2  CENCY701
# 179644       2015 Q3 (July-September)                   2015-16 Q2  CENCY701
# 179645       2015 Q3 (July-September)                   2015-16 Q2  CENCY701
# 179646       2015 Q3 (July-September)                   2015-16 Q2  CENCY701
# 179647       2015 Q3 (July-September)                   2015-16 Q2  CENCY701
#
#              Location    Survey date     Weather         Time  \
# 161984  Regent Street  lun, 14/09/15  Light Rain  0600 - 0615
# 161985  Regent Street  lun, 14/09/15  Light Rain  0615 - 0630
# 161986  Regent Street  lun, 14/09/15  Light Rain  0630 - 0645
# 161987  Regent Street  lun, 14/09/15  Light Rain  0645 - 0700
# 161988  Regent Street  lun, 14/09/15  Light Rain  0700 - 0715
# ...               ...            ...         ...          ...
# 179643  Regent Street  jeu, 30/07/15         Dry  2045 - 2100
# 179644  Regent Street  jeu, 30/07/15         Dry  2100 - 2115
# 179645  Regent Street  jeu, 30/07/15         Dry  2115 - 2130
# 179646  Regent Street  jeu, 30/07/15         Dry  2130 - 2145
# 179647  Regent Street  jeu, 30/07/15         Dry  2145 - 2200
#
#                              Period   Direction  Start hour  Start minute  \
# 161984  Early Morning (06:00-07:00)  Northbound         6.0           0.0
# 161985  Early Morning (06:00-07:00)  Northbound         6.0          15.0
# 161986  Early Morning (06:00-07:00)  Northbound         6.0          30.0
# 161987  Early Morning (06:00-07:00)  Northbound         6.0          45.0
# 161988        AM peak (07:00-10:00)  Northbound         7.0           0.0
# ...                             ...         ...         ...           ...
# 179643        Evening (19:00-22:00)  Southbound        20.0          45.0
# 179644        Evening (19:00-22:00)  Southbound        21.0           0.0
# 179645        Evening (19:00-22:00)  Southbound        21.0          15.0
# 179646        Evening (19:00-22:00)  Southbound        21.0          30.0
# 179647        Evening (19:00-22:00)  Southbound        21.0          45.0
#
#         Number of private cycles  Number of cycle hire bikes  Total cycles  \
# 161984                       0.0                         0.0           0.0
# 161985                       4.0                         0.0           4.0
# 161986                       4.0                         0.0           4.0
# 161987                       2.0                         0.0           2.0
# 161988                       6.0                         0.0           6.0
# ...                          ...                         ...           ...
# 179643                       0.0                         0.0           0.0
# 179644                       0.0                         0.0           0.0
# 179645                       0.0                         0.0           0.0
# 179646                       0.0                         0.0           0.0
# 179647                       0.0                         0.0           0.0
#
#         Survey_wave_year Survey_wave_quater Survey_wave_months Survey_date  \
# 161984              2015                 Q3     July-September    14/09/15
# 161985              2015                 Q3     July-September    14/09/15
# 161986              2015                 Q3     July-September    14/09/15
# 161987              2015                 Q3     July-September    14/09/15
# 161988              2015                 Q3     July-September    14/09/15
# ...                  ...                ...                ...         ...
# 179643              2015                 Q3     July-September    30/07/15
# 179644              2015                 Q3     July-September    30/07/15
# 179645              2015                 Q3     July-September    30/07/15
# 179646              2015                 Q3     July-September    30/07/15
# 179647              2015                 Q3     July-September    30/07/15
#
#        Survey_date_dt Year-Quarter
# 161984     2015-09-14      2015-Q3
# 161985     2015-09-14      2015-Q3
# 161986     2015-09-14      2015-Q3
# 161987     2015-09-14      2015-Q3
# 161988     2015-09-14      2015-Q3
# ...               ...          ...
# 179643     2015-07-30      2015-Q3
# 179644     2015-07-30      2015-Q3
# 179645     2015-07-30      2015-Q3
# 179646     2015-07-30      2015-Q3
# 179647     2015-07-30      2015-Q3
#
# [256 rows x 20 columns]

# %%
# View frequency of dates in 'Survey_date_dt' column.
Rst_15_Q3['Survey_date_dt'].value_counts(sort=False)
# Out:
# 2015-09-14    56
# 2015-09-16    72
# 2015-07-30    52
# 2015-07-31    38
# 2015-08-03    38
# Name: Survey_date_dt, dtype: int64

# %%
# See dates order.
b = Rst_15_Q3['Survey_date_dt'].drop_duplicates()
b

# No consistency of date order (by index), e.g. 2016-11-21 is in between of rows related to data for 2016-11-17. 
# BUT within Qs months are in descending order.
# Out:
# 161984   2015-09-14
# 162012   2015-09-16
# 179520   2015-07-30
# 179536   2015-07-31
# 179548   2015-08-03
# Name: Survey_date_dt, dtype: datetime64[ns]

# %%
# View frequency of sites in 'Site ID' column.
Rst_15_Q3['Site ID'].value_counts()
# Out:
# CENCY063    128
# CENCY701    128
# Name: Site ID, dtype: int64

# %%
# Check dates related to CENCY063 site ID in 2015 Q3.
Rst_15_Q3.loc[Rst_15_Q3['Site ID'] == 'CENCY063']['Survey_date_dt'].value_counts(sort=False)
# Out:
# 2015-09-14    56
# 2015-09-16    72
# Name: Survey_date_dt, dtype: int64

# %%
# Select rows from the main DataFrame with location 'Regent Street' and 'Survey wave (calendar quarter)' 
# column == 2015 Q1.
Rst_15_Q1 = L_centr_fnl_0[(L_centr_fnl_0['Location'] == 'Regent Street') & 
                          (L_centr_fnl_0['Survey wave (calendar quarter)'] == '2015 Q1 (January-March)')].sort_index()

Rst_15_Q1
# Out:
#        Survey wave (calendar quarter) Equivalent financial quarter   Site ID  \
# 110528        2015 Q1 (January-March)                   2014-15 Q4  CENCY063
# 110529        2015 Q1 (January-March)                   2014-15 Q4  CENCY063
# 110530        2015 Q1 (January-March)                   2014-15 Q4  CENCY063
# 110531        2015 Q1 (January-March)                   2014-15 Q4  CENCY063
# 110532        2015 Q1 (January-March)                   2014-15 Q4  CENCY063
# ...                               ...                          ...       ...
# 128187        2015 Q1 (January-March)                   2014-15 Q4  CENCY701
# 128188        2015 Q1 (January-March)                   2014-15 Q4  CENCY701
# 128189        2015 Q1 (January-March)                   2014-15 Q4  CENCY701
# 128190        2015 Q1 (January-March)                   2014-15 Q4  CENCY701
# 128191        2015 Q1 (January-March)                   2014-15 Q4  CENCY701
#
#              Location    Survey date Weather         Time  \
# 110528  Regent Street  mer, 25/03/15     Dry  0600 - 0615
# 110529  Regent Street  mer, 25/03/15     Dry  0615 - 0630
# 110530  Regent Street  mer, 25/03/15     Dry  0630 - 0645
# 110531  Regent Street  mer, 25/03/15     Dry  0645 - 0700
# 110532  Regent Street  mer, 25/03/15     Dry  0700 - 0715
# ...               ...            ...     ...          ...
# 128187  Regent Street  mer, 11/02/15     Dry  2045 - 2100
# 128188  Regent Street  mer, 11/02/15     Dry  2100 - 2115
# 128189  Regent Street  mer, 11/02/15     Dry  2115 - 2130
# 128190  Regent Street  mer, 11/02/15     Dry  2130 - 2145
# 128191  Regent Street  mer, 11/02/15     Dry  2145 - 2200
#
#                              Period   Direction  Start hour  Start minute  \
# 110528  Early Morning (06:00-07:00)  Northbound         6.0           0.0
# 110529  Early Morning (06:00-07:00)  Northbound         6.0          15.0
# 110530  Early Morning (06:00-07:00)  Northbound         6.0          30.0
# 110531  Early Morning (06:00-07:00)  Northbound         6.0          45.0
# 110532        AM peak (07:00-10:00)  Northbound         7.0           0.0
# ...                             ...         ...         ...           ...
# 128187        Evening (19:00-22:00)  Southbound        20.0          45.0
# 128188        Evening (19:00-22:00)  Southbound        21.0           0.0
# 128189        Evening (19:00-22:00)  Southbound        21.0          15.0
# 128190        Evening (19:00-22:00)  Southbound        21.0          30.0
# 128191        Evening (19:00-22:00)  Southbound        21.0          45.0
#
#         Number of private cycles  Number of cycle hire bikes  Total cycles  \
# 110528                       5.0                         0.0           5.0
# 110529                      20.0                         0.0          20.0
# 110530                       7.0                         0.0           7.0
# 110531                      14.0                         0.0          14.0
# 110532                      12.0                         0.0          12.0
# ...                          ...                         ...           ...
# 128187                       0.0                         0.0           0.0
# 128188                       1.0                         2.0           3.0
# 128189                       0.0                         0.0           0.0
# 128190                       0.0                         0.0           0.0
# 128191                       0.0                         0.0           0.0
#
#         Survey_wave_year Survey_wave_quater Survey_wave_months Survey_date  \
# 110528              2015                 Q1      January-March    25/03/15
# 110529              2015                 Q1      January-March    25/03/15
# 110530              2015                 Q1      January-March    25/03/15
# 110531              2015                 Q1      January-March    25/03/15
# 110532              2015                 Q1      January-March    25/03/15
# ...                  ...                ...                ...         ...
# 128187              2015                 Q1      January-March    11/02/15
# 128188              2015                 Q1      January-March    11/02/15
# 128189              2015                 Q1      January-March    11/02/15
# 128190              2015                 Q1      January-March    11/02/15
# 128191              2015                 Q1      January-March    11/02/15
#
#        Survey_date_dt Year-Quarter
# 110528     2015-03-25      2015-Q1
# 110529     2015-03-25      2015-Q1
# 110530     2015-03-25      2015-Q1
# 110531     2015-03-25      2015-Q1
# 110532     2015-03-25      2015-Q1
# ...               ...          ...
# 128187     2015-02-11      2015-Q1
# 128188     2015-02-11      2015-Q1
# 128189     2015-02-11      2015-Q1
# 128190     2015-02-11      2015-Q1
# 128191     2015-02-11      2015-Q1
#
# [256 rows x 20 columns]

# %%
# View frequency of dates in 'Survey_date_dt' column.
Rst_15_Q1['Survey_date_dt'].value_counts(sort=False)
# Out:
# 2015-03-25    64
# 2015-03-16    64
# 2015-02-10    64
# 2015-02-11    64
# Name: Survey_date_dt, dtype: int64

# %%
# View frequency of sites in 'Site ID' column.
Rst_15_Q1['Site ID'].value_counts()
# Out:
# CENCY063    128
# CENCY701    128
# Name: Site ID, dtype: int64

# %%
# Check dates related to CENCY063 site ID in 2015 Q1.
Rst_15_Q1.loc[Rst_15_Q1['Site ID'] == 'CENCY063']['Survey_date_dt'].value_counts(sort=False)
# Out:
# 2015-03-25    64
# 2015-03-16    64
# Name: Survey_date_dt, dtype: int64

# %%
# Select rows from the main DataFrame with location 'Regent Street' and 'Survey wave (calendar quarter)' 
# column == 2015 Q2.
Rst_15_Q2 = L_centr_fnl_0[(L_centr_fnl_0['Location'] == 'Regent Street') & 
                          (L_centr_fnl_0['Survey wave (calendar quarter)'] == '2015 Q2 (April-June)')].sort_index()

Rst_15_Q2
# Out:
#        Survey wave (calendar quarter) Equivalent financial quarter   Site ID  \
# 136256           2015 Q2 (April-June)                   2015-16 Q1  CENCY063
# 136257           2015 Q2 (April-June)                   2015-16 Q1  CENCY063
# 136258           2015 Q2 (April-June)                   2015-16 Q1  CENCY063
# 136259           2015 Q2 (April-June)                   2015-16 Q1  CENCY063
# 136260           2015 Q2 (April-June)                   2015-16 Q1  CENCY063
# ...                               ...                          ...       ...
# 153915           2015 Q2 (April-June)                   2015-16 Q1  CENCY701
# 153916           2015 Q2 (April-June)                   2015-16 Q1  CENCY701
# 153917           2015 Q2 (April-June)                   2015-16 Q1  CENCY701
# 153918           2015 Q2 (April-June)                   2015-16 Q1  CENCY701
# 153919           2015 Q2 (April-June)                   2015-16 Q1  CENCY701
#
#              Location    Survey date Weather         Time  \
# 136256  Regent Street  lun, 15/06/15     Dry  0600 - 0615
# 136257  Regent Street  lun, 15/06/15     Dry  0615 - 0630
# 136258  Regent Street  lun, 15/06/15     Dry  0630 - 0645
# 136259  Regent Street  lun, 15/06/15     Dry  0645 - 0700
# 136260  Regent Street  lun, 15/06/15     Dry  0700 - 0715
# ...               ...            ...     ...          ...
# 153915  Regent Street  ven, 15/05/15     Dry  2045 - 2100
# 153916  Regent Street  ven, 15/05/15     Dry  2100 - 2115
# 153917  Regent Street  ven, 15/05/15     Dry  2115 - 2130
# 153918  Regent Street  ven, 15/05/15     Dry  2130 - 2145
# 153919  Regent Street  ven, 15/05/15     Dry  2145 - 2200
#
#                              Period   Direction  Start hour  Start minute  \
# 136256  Early Morning (06:00-07:00)  Northbound         6.0           0.0
# 136257  Early Morning (06:00-07:00)  Northbound         6.0          15.0
# 136258  Early Morning (06:00-07:00)  Northbound         6.0          30.0
# 136259  Early Morning (06:00-07:00)  Northbound         6.0          45.0
# 136260        AM peak (07:00-10:00)  Northbound         7.0           0.0
# ...                             ...         ...         ...           ...
# 153915        Evening (19:00-22:00)  Southbound        20.0          45.0
# 153916        Evening (19:00-22:00)  Southbound        21.0           0.0
# 153917        Evening (19:00-22:00)  Southbound        21.0          15.0
# 153918        Evening (19:00-22:00)  Southbound        21.0          30.0
# 153919        Evening (19:00-22:00)  Southbound        21.0          45.0
#
#         Number of private cycles  Number of cycle hire bikes  Total cycles  \
# 136256                       0.0                         0.0           0.0
# 136257                       4.0                         0.0           4.0
# 136258                       5.0                         0.0           5.0
# 136259                       6.0                         1.0           7.0
# 136260                       8.0                         1.0           9.0
# ...                          ...                         ...           ...
# 153915                       0.0                         0.0           0.0
# 153916                       0.0                         0.0           0.0
# 153917                       0.0                         0.0           0.0
# 153918                       0.0                         0.0           0.0
# 153919                       0.0                         0.0           0.0
#
#         Survey_wave_year Survey_wave_quater Survey_wave_months Survey_date  \
# 136256              2015                 Q2         April-June    15/06/15
# 136257              2015                 Q2         April-June    15/06/15
# 136258              2015                 Q2         April-June    15/06/15
# 136259              2015                 Q2         April-June    15/06/15
# 136260              2015                 Q2         April-June    15/06/15
# ...                  ...                ...                ...         ...
# 153915              2015                 Q2         April-June    15/05/15
# 153916              2015                 Q2         April-June    15/05/15
# 153917              2015                 Q2         April-June    15/05/15
# 153918              2015                 Q2         April-June    15/05/15
# 153919              2015                 Q2         April-June    15/05/15
#
#        Survey_date_dt Year-Quarter
# 136256     2015-06-15      2015-Q2
# 136257     2015-06-15      2015-Q2
# 136258     2015-06-15      2015-Q2
# 136259     2015-06-15      2015-Q2
# 136260     2015-06-15      2015-Q2
# ...               ...          ...
# 153915     2015-05-15      2015-Q2
# 153916     2015-05-15      2015-Q2
# 153917     2015-05-15      2015-Q2
# 153918     2015-05-15      2015-Q2
# 153919     2015-05-15      2015-Q2
#
# [256 rows x 20 columns]

# %%
# View frequency of dates in 'Survey_date_dt' column.
Rst_15_Q2['Survey_date_dt'].value_counts(sort=False)
# Out:
# 2015-06-15    56
# 2015-06-24    72
# 2015-05-14    64
# 2015-05-15    64
# Name: Survey_date_dt, dtype: int64

# %%
# View frequency of sites in 'Site ID' column.
Rst_15_Q2['Site ID'].value_counts()
# Out:
# CENCY063    128
# CENCY701    128
# Name: Site ID, dtype: int64

# %%
# Check dates related to CENCY063 site ID in 2015 Q2.
Rst_15_Q2.loc[Rst_15_Q2['Site ID'] == 'CENCY063']['Survey_date_dt'].value_counts(sort=False)
# Out:
# 2015-06-15    56
# 2015-06-24    72
# Name: Survey_date_dt, dtype: int64

# %%
# Select rows from the main DataFrame with location 'Regent Street' and 'Survey wave (calendar quarter)' 
# column == 2015 Q4.
Rst_15_Q4 = L_centr_fnl_0[(L_centr_fnl_0['Location'] == 'Regent Street') & 
                          (L_centr_fnl_0['Survey wave (calendar quarter)'] == '2015 Q4 (October-December)')].sort_index()

Rst_15_Q4
# Out:
#        Survey wave (calendar quarter) Equivalent financial quarter   Site ID  \
# 187712     2015 Q4 (October-December)                   2015-16 Q3  CENCY063
# 187713     2015 Q4 (October-December)                   2015-16 Q3  CENCY063
# 187714     2015 Q4 (October-December)                   2015-16 Q3  CENCY063
# 187715     2015 Q4 (October-December)                   2015-16 Q3  CENCY063
# 187716     2015 Q4 (October-December)                   2015-16 Q3  CENCY063
# ...                               ...                          ...       ...
# 205371     2015 Q4 (October-December)                   2015-16 Q3  CENCY701
# 205372     2015 Q4 (October-December)                   2015-16 Q3  CENCY701
# 205373     2015 Q4 (October-December)                   2015-16 Q3  CENCY701
# 205374     2015 Q4 (October-December)                   2015-16 Q3  CENCY701
# 205375     2015 Q4 (October-December)                   2015-16 Q3  CENCY701
#
#              Location    Survey date Weather         Time  \
# 187712  Regent Street  jeu, 03/12/15     Dry  0600 - 0615
# 187713  Regent Street  jeu, 03/12/15     Dry  0615 - 0630
# 187714  Regent Street  jeu, 03/12/15     Dry  0630 - 0645
# 187715  Regent Street  jeu, 03/12/15     Dry  0645 - 0700
# 187716  Regent Street  jeu, 03/12/15     Dry  0700 - 0715
# ...               ...            ...     ...          ...
# 205371  Regent Street  mar, 03/11/15     Dry  2045 - 2100
# 205372  Regent Street  mar, 03/11/15     Dry  2100 - 2115
# 205373  Regent Street  mar, 03/11/15     Dry  2115 - 2130
# 205374  Regent Street  mar, 03/11/15     Dry  2130 - 2145
# 205375  Regent Street  mar, 03/11/15     Dry  2145 - 2200
#
#                              Period   Direction  Start hour  Start minute  \
# 187712  Early Morning (06:00-07:00)  Northbound         6.0           0.0
# 187713  Early Morning (06:00-07:00)  Northbound         6.0          15.0
# 187714  Early Morning (06:00-07:00)  Northbound         6.0          30.0
# 187715  Early Morning (06:00-07:00)  Northbound         6.0          45.0
# 187716        AM peak (07:00-10:00)  Northbound         7.0           0.0
# ...                             ...         ...         ...           ...
# 205371        Evening (19:00-22:00)  Southbound        20.0          45.0
# 205372        Evening (19:00-22:00)  Southbound        21.0           0.0
# 205373        Evening (19:00-22:00)  Southbound        21.0          15.0
# 205374        Evening (19:00-22:00)  Southbound        21.0          30.0
# 205375        Evening (19:00-22:00)  Southbound        21.0          45.0
#
#         Number of private cycles  Number of cycle hire bikes  Total cycles  \
# 187712                       0.0                         0.0           0.0
# 187713                      13.0                         2.0          15.0
# 187714                       8.0                         1.0           9.0
# 187715                       9.0                         0.0           9.0
# 187716                       1.0                         0.0           1.0
# ...                          ...                         ...           ...
# 205371                       1.0                         0.0           1.0
# 205372                       0.0                         0.0           0.0
# 205373                       0.0                         0.0           0.0
# 205374                       0.0                         0.0           0.0
# 205375                       0.0                         0.0           0.0
#
#         Survey_wave_year Survey_wave_quater Survey_wave_months Survey_date  \
# 187712              2015                 Q4   October-December    03/12/15
# 187713              2015                 Q4   October-December    03/12/15
# 187714              2015                 Q4   October-December    03/12/15
# 187715              2015                 Q4   October-December    03/12/15
# 187716              2015                 Q4   October-December    03/12/15
# ...                  ...                ...                ...         ...
# 205371              2015                 Q4   October-December    03/11/15
# 205372              2015                 Q4   October-December    03/11/15
# 205373              2015                 Q4   October-December    03/11/15
# 205374              2015                 Q4   October-December    03/11/15
# 205375              2015                 Q4   October-December    03/11/15
#
#        Survey_date_dt Year-Quarter
# 187712     2015-12-03      2015-Q4
# 187713     2015-12-03      2015-Q4
# 187714     2015-12-03      2015-Q4
# 187715     2015-12-03      2015-Q4
# 187716     2015-12-03      2015-Q4
# ...               ...          ...
# 205371     2015-11-03      2015-Q4
# 205372     2015-11-03      2015-Q4
# 205373     2015-11-03      2015-Q4
# 205374     2015-11-03      2015-Q4
# 205375     2015-11-03      2015-Q4
#
# [256 rows x 20 columns]

# %%
# View frequency of dates in 'Survey_date_dt' column.
Rst_15_Q4['Survey_date_dt'].value_counts(sort=False)
# Out:
# 2015-12-03    64
# 2015-12-04    64
# 2015-11-05    32
# 2015-11-03    64
# 2015-11-02    32
# Name: Survey_date_dt, dtype: int64

# %%
# View frequency of sites in 'Site ID' column.
Rst_15_Q4['Site ID'].value_counts()
# Out:
# CENCY063    128
# CENCY701    128
# Name: Site ID, dtype: int64

# %%
# Check dates related to CENCY063 site ID in 2015 Q4.
Rst_15_Q4.loc[Rst_15_Q4['Site ID'] == 'CENCY063']['Survey_date_dt'].value_counts(sort=False)
# Out:
# 2015-12-03    64
# 2015-12-04    64
# Name: Survey_date_dt, dtype: int64

# %% [markdown]
# **OBSERVATIONS AND INSIGHTS:**
#
# 7424 observations
# 128 NaN - all related to 2016 Q3 (July-September)
# 256 observations per Q
# 2 sites/locations: CENCY063 and CENCY701
# 128 entries per site ID in each Q
# 64 time slots per day from 6am to 10 pm (every 15 mins) **SOMETIMES SPLIT BETWEEN DATES**
# All missing values are related to CENCY701 site ID (128 entries)
#
# No consistency of date order (by index), e.g. 2016-11-21 is in between of rows related to data for 2016-11-17.
# BUT months within each Q are **ALMOST** all in the descending order.
# Observations from different site IDs were recorded in different months => CENCY063 - always last month of Q;
# CENCY701 – 1st or/and 2nd month of Q.
#
# **Therefore the decision was made to keep the missing dates (1.37% of all entries) as NaT**

# %%
# Drop 'Survey_date' column.
L_centr_fnl_0 = L_centr_fnl_0.drop(columns=['Survey_date']).reset_index(drop=True)

# %%
# Rename 'Survey_date_dt' column into 'Date'.
L_centr_fnl_0 = L_centr_fnl_0.rename(columns={'Survey_date_dt':'Date'})

# View DataFrame.
L_centr_fnl_0.head()
# Out:
#   Survey wave (calendar quarter) Equivalent financial quarter   Site ID  \
# 0        2014 Q1 (January-March)                   2013-14 Q4  CENCY001
# 1        2014 Q1 (January-March)                   2013-14 Q4  CENCY001
# 2        2014 Q1 (January-March)                   2013-14 Q4  CENCY001
# 3        2014 Q1 (January-March)                   2013-14 Q4  CENCY001
# 4        2014 Q1 (January-March)                   2013-14 Q4  CENCY001
#
#                              Location    Survey date Weather         Time  \
# 0  Millbank (south of Thorney Street)  ven, 24/01/14     Dry  0600 - 0615
# 1  Millbank (south of Thorney Street)  ven, 24/01/14     Dry  0615 - 0630
# 2  Millbank (south of Thorney Street)  ven, 24/01/14     Dry  0630 - 0645
# 3  Millbank (south of Thorney Street)  ven, 24/01/14     Dry  0645 - 0700
# 4  Millbank (south of Thorney Street)  ven, 24/01/14     Dry  0700 - 0715
#
#                         Period   Direction  Start hour  Start minute  \
# 0  Early Morning (06:00-07:00)  Northbound         6.0           0.0
# 1  Early Morning (06:00-07:00)  Northbound         6.0          15.0
# 2  Early Morning (06:00-07:00)  Northbound         6.0          30.0
# 3  Early Morning (06:00-07:00)  Northbound         6.0          45.0
# 4        AM peak (07:00-10:00)  Northbound         7.0           0.0
#
#    Number of private cycles  Number of cycle hire bikes  Total cycles  \
# 0                       0.0                         0.0           0.0
# 1                      15.0                         0.0          15.0
# 2                      35.0                         0.0          35.0
# 3                      59.0                         2.0          61.0
# 4                      73.0                         0.0          73.0
#
#    Survey_wave_year Survey_wave_quater Survey_wave_months       Date  \
# 0              2014                 Q1      January-March 2014-01-24
# 1              2014                 Q1      January-March 2014-01-24
# 2              2014                 Q1      January-March 2014-01-24
# 3              2014                 Q1      January-March 2014-01-24
# 4              2014                 Q1      January-March 2014-01-24
#
#   Year-Quarter
# 0      2014-Q1
# 1      2014-Q1
# 2      2014-Q1
# 3      2014-Q1
# 4      2014-Q1

# %%
# Add a column with days of the week.
L_centr_fnl_0['Day'] = L_centr_fnl_0['Date'].dt.day_name()

# View DataFrame.
L_centr_fnl_0.head()
# Out:
#   Survey wave (calendar quarter) Equivalent financial quarter   Site ID  \
# 0        2014 Q1 (January-March)                   2013-14 Q4  CENCY001
# 1        2014 Q1 (January-March)                   2013-14 Q4  CENCY001
# 2        2014 Q1 (January-March)                   2013-14 Q4  CENCY001
# 3        2014 Q1 (January-March)                   2013-14 Q4  CENCY001
# 4        2014 Q1 (January-March)                   2013-14 Q4  CENCY001
#
#                              Location    Survey date Weather         Time  \
# 0  Millbank (south of Thorney Street)  ven, 24/01/14     Dry  0600 - 0615
# 1  Millbank (south of Thorney Street)  ven, 24/01/14     Dry  0615 - 0630
# 2  Millbank (south of Thorney Street)  ven, 24/01/14     Dry  0630 - 0645
# 3  Millbank (south of Thorney Street)  ven, 24/01/14     Dry  0645 - 0700
# 4  Millbank (south of Thorney Street)  ven, 24/01/14     Dry  0700 - 0715
#
#                         Period   Direction  Start hour  Start minute  \
# 0  Early Morning (06:00-07:00)  Northbound         6.0           0.0
# 1  Early Morning (06:00-07:00)  Northbound         6.0          15.0
# 2  Early Morning (06:00-07:00)  Northbound         6.0          30.0
# 3  Early Morning (06:00-07:00)  Northbound         6.0          45.0
# 4        AM peak (07:00-10:00)  Northbound         7.0           0.0
#
#    Number of private cycles  Number of cycle hire bikes  Total cycles  \
# 0                       0.0                         0.0           0.0
# 1                      15.0                         0.0          15.0
# 2                      35.0                         0.0          35.0
# 3                      59.0                         2.0          61.0
# 4                      73.0                         0.0          73.0
#
#    Survey_wave_year Survey_wave_quater Survey_wave_months       Date  \
# 0              2014                 Q1      January-March 2014-01-24
# 1              2014                 Q1      January-March 2014-01-24
# 2              2014                 Q1      January-March 2014-01-24
# 3              2014                 Q1      January-March 2014-01-24
# 4              2014                 Q1      January-March 2014-01-24
#
#   Year-Quarter     Day
# 0      2014-Q1  Friday
# 1      2014-Q1  Friday
# 2      2014-Q1  Friday
# 3      2014-Q1  Friday
# 4      2014-Q1  Friday

# %%
# Check info.
L_centr_fnl_0.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 758163 entries, 0 to 758162
# Data columns (total 20 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   Survey wave (calendar quarter)  758163 non-null  object
#  1   Equivalent financial quarter    758163 non-null  object
#  2   Site ID                         758163 non-null  object
#  3   Location                        758163 non-null  object
#  4   Survey date                     747751 non-null  object
#  5   Weather                         746329 non-null  object
#  6   Time                            758163 non-null  object
#  7   Period                          758163 non-null  object
#  8   Direction                       758163 non-null  object
#  9   Start hour                      758163 non-null  float64
#  10  Start minute                    758163 non-null  float64
#  11  Number of private cycles        758099 non-null  float64
#  12  Number of cycle hire bikes      758099 non-null  float64
#  13  Total cycles                    758163 non-null  float64
#  14  Survey_wave_year                758163 non-null  int64
#  15  Survey_wave_quater              758163 non-null  object
#  16  Survey_wave_months              758163 non-null  object
#  17  Date                            747751 non-null  datetime64[ns]
#  18  Year-Quarter                    758163 non-null  object
#  19  Day                             747751 non-null  object
# dtypes: datetime64[ns](1), float64(5), int64(1), object(13)
# memory usage: 115.7+ MB

# %%
# Check info.
L_centr_fnl_0.isnull().sum()
# Out:
# Survey wave (calendar quarter)        0
# Equivalent financial quarter          0
# Site ID                               0
# Location                              0
# Survey date                       10412
# Weather                           11834
# Time                                  0
# Period                                0
# Direction                             0
# Start hour                            0
# Start minute                          0
# Number of private cycles             64
# Number of cycle hire bikes           64
# Total cycles                          0
# Survey_wave_year                      0
# Survey_wave_quater                    0
# Survey_wave_months                    0
# Date                              10412
# Year-Quarter                          0
# Day                               10412
# dtype: int64

# %% [markdown]
# ## Investigating missing values in 'Number of private cycles' and 'Number of cycle hire bikes' columns

# %%
# Look at rows with missing values for Number of private cycles and Number of cycle hire bikes.
BC_0 = L_centr_fnl_0[(L_centr_fnl_0['Number of private cycles'].isnull()) | 
                     (L_centr_fnl_0['Number of cycle hire bikes'].isnull())]

# View DataFrame.
BC_0
# The same rows have NaN for both columns.
# Out:
#        Survey wave (calendar quarter) Equivalent financial quarter   Site ID  \
# 718779       2021 Q3 (July-September)                   2021-22 Q2  CENCY112
# 718780       2021 Q3 (July-September)                   2021-22 Q2  CENCY112
# 718781       2021 Q3 (July-September)                   2021-22 Q2  CENCY112
# 718782       2021 Q3 (July-September)                   2021-22 Q2  CENCY112
# 718783       2021 Q3 (July-September)                   2021-22 Q2  CENCY112
# ...                               ...                          ...       ...
# 718838       2021 Q3 (July-September)                   2021-22 Q2  CENCY112
# 718839       2021 Q3 (July-September)                   2021-22 Q2  CENCY112
# 718840       2021 Q3 (July-September)                   2021-22 Q2  CENCY112
# 718841       2021 Q3 (July-September)                   2021-22 Q2  CENCY112
# 718842       2021 Q3 (July-September)                   2021-22 Q2  CENCY112
#
#                 Location    Survey date Weather         Time  \
# 718779  Grosvenor Street  mer, 18/08/21     Dry  0600 - 0615
# 718780  Grosvenor Street  mer, 18/08/21     Dry  0615 - 0630
# 718781  Grosvenor Street  mer, 18/08/21     Dry  0630 - 0645
# 718782  Grosvenor Street  mer, 18/08/21     Dry  0645 - 0700
# 718783  Grosvenor Street  mer, 18/08/21     Dry  0700 - 0715
# ...                  ...            ...     ...          ...
# 718838  Grosvenor Street  mar, 24/08/21     Dry  2045 - 2100
# 718839  Grosvenor Street  mar, 24/08/21     Dry  2100 - 2115
# 718840  Grosvenor Street  mar, 24/08/21     Dry  2115 - 2130
# 718841  Grosvenor Street  mar, 24/08/21     Dry  2130 - 2145
# 718842  Grosvenor Street  mar, 24/08/21     Dry  2145 - 2200
#
#                              Period  Direction  Start hour  Start minute  \
# 718779  Early Morning (06:00-07:00)  Eastbound         6.0           0.0
# 718780  Early Morning (06:00-07:00)  Eastbound         6.0          15.0
# 718781  Early Morning (06:00-07:00)  Eastbound         6.0          30.0
# 718782  Early Morning (06:00-07:00)  Eastbound         6.0          45.0
# 718783        AM peak (07:00-10:00)  Eastbound         7.0           0.0
# ...                             ...        ...         ...           ...
# 718838        Evening (19:00-22:00)  Eastbound        20.0          45.0
# 718839        Evening (19:00-22:00)  Eastbound        21.0           0.0
# 718840        Evening (19:00-22:00)  Eastbound        21.0          15.0
# 718841        Evening (19:00-22:00)  Eastbound        21.0          30.0
# 718842        Evening (19:00-22:00)  Eastbound        21.0          45.0
#
#         Number of private cycles  Number of cycle hire bikes  Total cycles  \
# 718779                       NaN                         NaN           0.0
# 718780                       NaN                         NaN           0.0
# 718781                       NaN                         NaN           0.0
# 718782                       NaN                         NaN           0.0
# 718783                       NaN                         NaN           0.0
# ...                          ...                         ...           ...
# 718838                       NaN                         NaN           0.0
# 718839                       NaN                         NaN           0.0
# 718840                       NaN                         NaN           0.0
# 718841                       NaN                         NaN           0.0
# 718842                       NaN                         NaN           0.0
#
#         Survey_wave_year Survey_wave_quater Survey_wave_months       Date  \
# 718779              2021                 Q3     July-September 2021-08-18
# 718780              2021                 Q3     July-September 2021-08-18
# 718781              2021                 Q3     July-September 2021-08-18
# 718782              2021                 Q3     July-September 2021-08-18
# 718783              2021                 Q3     July-September 2021-08-18
# ...                  ...                ...                ...        ...
# 718838              2021                 Q3     July-September 2021-08-24
# 718839              2021                 Q3     July-September 2021-08-24
# 718840              2021                 Q3     July-September 2021-08-24
# 718841              2021                 Q3     July-September 2021-08-24
# 718842              2021                 Q3     July-September 2021-08-24
#
#        Year-Quarter        Day
# 718779      2021-Q3  Wednesday
# 718780      2021-Q3  Wednesday
# 718781      2021-Q3  Wednesday
# 718782      2021-Q3  Wednesday
# 718783      2021-Q3  Wednesday
# ...             ...        ...
# 718838      2021-Q3    Tuesday
# 718839      2021-Q3    Tuesday
# 718840      2021-Q3    Tuesday
# 718841      2021-Q3    Tuesday
# 718842      2021-Q3    Tuesday
#
# [64 rows x 20 columns]

# %%
# Check if DataFrame has any missing dates.
BC_0[BC_0['Date'].isnull()]
# Out:
# Empty DataFrame
# Columns: [Survey wave (calendar quarter), Equivalent financial quarter, Site ID, Location, Survey date, Weather, Time, Period, Direction, Start hour, Start minute, Number of private cycles, Number of cycle hire bikes, Total cycles, Survey_wave_year, Survey_wave_quater, Survey_wave_months, Date, Year-Quarter, Day]
# Index: []

# %%
# Run a test of the skewness 
L_centr_fnl_0.skew(axis = 0, skipna = True)

# The puurpose of determining the skew is to see which measure of central tendancy (mean, mode, median) would be 
# best to use to replace the missing values. Due to the data being skewed we will replace values using the median.
# Out:
# Start hour                    0.000214
# Start minute                  0.000003
# Number of private cycles      5.136676
# Number of cycle hire bikes    5.150004
# Total cycles                  5.037641
# Survey_wave_year              0.139991
# dtype: float64

# %%
# Descriptive statistics.
L_centr_fnl_0.describe()

# Median for 'Number of private cycles' = 7; median for 'Number of cycle hire bikes' = 1.
# Out:
#           Start hour   Start minute  Number of private cycles  \
# count  758163.000000  758163.000000             758099.000000
# mean       13.499259      22.499951                 14.824374
# std         4.609643      16.770530                 26.255858
# min         6.000000       0.000000                  0.000000
# 25%         9.000000       0.000000                  2.000000
# 50%        13.000000      15.000000                  7.000000
# 75%        17.000000      30.000000                 16.000000
# max        21.000000      45.000000               1177.000000
#
#        Number of cycle hire bikes   Total cycles  Survey_wave_year
# count               758099.000000  758163.000000     758163.000000
# mean                     1.830072      16.653040       2017.232831
# std                      3.321560      28.675116          2.196612
# min                      0.000000       0.000000       2014.000000
# 25%                      0.000000       3.000000       2015.000000
# 50%                      1.000000       8.000000       2017.000000
# 75%                      2.000000      18.000000       2019.000000
# max                    108.000000    1200.000000       2021.000000

# %%
# Replace all NaN values with the median. 
L_centr_fnl_0['Number of private cycles'].fillna(7, inplace = True)

# Check for any missing values.
L_centr_fnl_0['Number of private cycles'].isnull().sum()
# Out:
# 0

# %%
# Replace all NaN values with the median. 
L_centr_fnl_0['Number of cycle hire bikes'].fillna(1, inplace = True)

# Check for any missing values.
L_centr_fnl_0['Number of cycle hire bikes'].isnull().sum()
# Out:
# 0

# %%
# Recalculate the 'Total cycles' column.
L_centr_fnl_0['Total_cycles'] = L_centr_fnl_0['Number of private cycles'] + L_centr_fnl_0['Number of cycle hire bikes']

# %%
# Drop 'Total cycles' column.
L_centr_fnl_0 = L_centr_fnl_0.drop(columns=['Total cycles']).reset_index(drop=True)

# %%
# Descriptive statistics.
L_centr_fnl_0.describe()

# Count shows that the NaN values were replaced.
# Out:
#           Start hour   Start minute  Number of private cycles  \
# count  758163.000000  758163.000000             758163.000000
# mean       13.499259      22.499951                 14.823713
# std         4.609643      16.770530                 26.254848
# min         6.000000       0.000000                  0.000000
# 25%         9.000000       0.000000                  2.000000
# 50%        13.000000      15.000000                  7.000000
# 75%        17.000000      30.000000                 16.000000
# max        21.000000      45.000000               1177.000000
#
#        Number of cycle hire bikes  Survey_wave_year   Total_cycles
# count               758163.000000     758163.000000  758163.000000
# mean                     1.830002       2017.232831      16.653716
# std                      3.321428          2.196612      28.674818
# min                      0.000000       2014.000000       0.000000
# 25%                      0.000000       2015.000000       3.000000
# 50%                      1.000000       2017.000000       8.000000
# 75%                      2.000000       2019.000000      18.000000
# max                    108.000000       2021.000000    1200.000000

# %%
# Convert 'Number of private cycles', 'Number of cycle hire bikes' and 'Total_cycles' Dtypes to integer.
L_centr_fnl_0['Number of private cycles'] = L_centr_fnl_0['Number of private cycles'].astype(int)
L_centr_fnl_0['Number of cycle hire bikes'] = L_centr_fnl_0['Number of cycle hire bikes'].astype(int)
L_centr_fnl_0['Total_cycles'] = L_centr_fnl_0['Total_cycles'].astype(int)

# Check Dtypes.
L_centr_fnl_0.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 758163 entries, 0 to 758162
# Data columns (total 20 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   Survey wave (calendar quarter)  758163 non-null  object
#  1   Equivalent financial quarter    758163 non-null  object
#  2   Site ID                         758163 non-null  object
#  3   Location                        758163 non-null  object
#  4   Survey date                     747751 non-null  object
#  5   Weather                         746329 non-null  object
#  6   Time                            758163 non-null  object
#  7   Period                          758163 non-null  object
#  8   Direction                       758163 non-null  object
#  9   Start hour                      758163 non-null  float64
#  10  Start minute                    758163 non-null  float64
#  11  Number of private cycles        758163 non-null  int64
#  12  Number of cycle hire bikes      758163 non-null  int64
#  13  Survey_wave_year                758163 non-null  int64
#  14  Survey_wave_quater              758163 non-null  object
#  15  Survey_wave_months              758163 non-null  object
#  16  Date                            747751 non-null  datetime64[ns]
#  17  Year-Quarter                    758163 non-null  object
#  18  Day                             747751 non-null  object
#  19  Total_cycles                    758163 non-null  int64
# dtypes: datetime64[ns](1), float64(2), int64(4), object(13)
# memory usage: 115.7+ MB

# %%
# Exported as csv file 
L_centr_fnl_0.to_csv('L_centr_fnl_0.csv')

# %% [markdown]
# ## Insights and observations related to Date and Time

# %%
# What year has the largest number of records?
L_centr_fnl_0['Survey_wave_year'].value_counts()
# Out:
# 2019    107264
# 2018    106368
# 2017    104960
# 2015    102912
# 2016    102656
# 2014    102592
# 2021     77651
# 2020     53760
# Name: Survey_wave_year, dtype: int64

# %%
# Total number of cycle trips per calendar year.
year_ttl = L_centr_fnl_0.groupby('Survey_wave_year')\
[['Total_cycles']].sum().reset_index().sort_values('Total_cycles', ascending=0)

# View DataFrame.
year_ttl
# Out:
#    Survey_wave_year  Total_cycles
# 5              2019       1907780
# 4              2018       1891445
# 3              2017       1739414
# 2              2016       1724842
# 1              2015       1636501
# 0              2014       1603639
# 7              2021       1269959
# 6              2020        852651

# %%
# What year has the highest average number of cycles (every 15 mins)?
year_15mns = L_centr_fnl_0.groupby('Survey_wave_year')\
[['Total_cycles']].mean().round(0).reset_index().sort_values('Total_cycles', ascending=0)

# View DataFrame.
year_15mns
# Out:
#    Survey_wave_year  Total_cycles
# 4              2018          18.0
# 5              2019          18.0
# 2              2016          17.0
# 3              2017          17.0
# 0              2014          16.0
# 1              2015          16.0
# 6              2020          16.0
# 7              2021          16.0

# %%
# What quater has the largest number of records?
L_centr_fnl_0['Survey_wave_quater'].value_counts()
# Out:
# Q3    211032
# Q4    184192
# Q1    181952
# Q2    180987
# Name: Survey_wave_quater, dtype: int64

# %%
# Total number of cycle trips per calendar quater.
Q_ttl = L_centr_fnl_0.groupby('Survey_wave_quater')\
[['Total_cycles']].sum().reset_index().sort_values('Total_cycles', ascending=0).reset_index(drop=True)

# View DataFrame.
Q_ttl
# Out:
#   Survey_wave_quater  Total_cycles
# 0                 Q3       3779402
# 1                 Q2       3206638
# 2                 Q4       2926232
# 3                 Q1       2713959

# %%
# What quater has the highest average number of cycles (every 15 mins)?
Q_15mns = L_centr_fnl_0.groupby('Survey_wave_quater')\
[['Total_cycles']].mean().round(0).reset_index().sort_values('Total_cycles', ascending=0).reset_index(drop=True)

# View DataFrame.
Q_15mns
# Out:
#   Survey_wave_quater  Total_cycles
# 0                 Q2          18.0
# 1                 Q3          18.0
# 2                 Q4          16.0
# 3                 Q1          15.0

# %%
# Top 10 dates with the highest number of cycle trips?
date_ttl = L_centr_fnl_0.groupby('Date')\
[['Total_cycles']].sum().reset_index().sort_values('Total_cycles', ascending=0).reset_index(drop=True)

# View DataFrame.
date_ttl.head(10)
# Out:
#         Date  Total_cycles
# 0 2014-01-23         38849
# 1 2014-01-27         36725
# 2 2014-01-30         36265
# 3 2014-02-03         31184
# 4 2019-09-10         30507
# 5 2014-01-28         29441
# 6 2018-06-26         28486
# 7 2018-04-17         28325
# 8 2015-06-30         27462
# 9 2017-07-12         26882

# %%
# Top 10 dates with the highest average number of cycles (every 15 mins)?
date_15mns = L_centr_fnl_0.groupby('Date')\
[['Total_cycles']].mean().round(0).reset_index().sort_values('Total_cycles', ascending=0).reset_index(drop=True)

# View DataFrame.
date_15mns.head(10)
# Out:
#         Date  Total_cycles
# 0 2019-05-27          80.0
# 1 2019-09-02          77.0
# 2 2021-11-25          68.0
# 3 2017-10-02          59.0
# 4 2019-02-18          52.0
# 5 2020-01-06          52.0
# 6 2019-02-21          46.0
# 7 2021-11-24          45.0
# 8 2018-09-24          42.0
# 9 2018-05-17          40.0

# %%
# Total number of cycle trips per Year-Quarter.
year_Q_ttl = L_centr_fnl_0.groupby('Year-Quarter')\
[['Total_cycles']].sum().reset_index().sort_values('Total_cycles', ascending=0).\
reset_index(drop=True)

# View DataFrame (top 10).
year_Q_ttl.head(10)
# Out:
#   Year-Quarter  Total_cycles
# 0      2019-Q3        534472
# 1      2018-Q2        521756
# 2      2018-Q3        520788
# 3      2019-Q2        502231
# 4      2016-Q3        483653
# 5      2017-Q3        466209
# 6      2017-Q2        464864
# 7      2018-Q4        460898
# 8      2014-Q3        456591
# 9      2021-Q3        455139

# %%
# What year & Q has the highest average number of cycles (every 15 mins)?
year_Q_15mns = L_centr_fnl_0.groupby('Year-Quarter')\
[['Total_cycles']].mean().round(0).reset_index().sort_values('Total_cycles', ascending=0).\
reset_index(drop=True)

# View DataFrame (top 10).
year_Q_15mns.head(10)
# Out:
#   Year-Quarter  Total_cycles
# 0      2019-Q3          20.0
# 1      2018-Q2          19.0
# 2      2018-Q3          19.0
# 3      2019-Q2          19.0
# 4      2016-Q3          19.0
# 5      2017-Q2          18.0
# 6      2016-Q2          18.0
# 7      2014-Q3          18.0
# 8      2019-Q4          17.0
# 9      2015-Q3          17.0

# %%
# Total number of cycle trips per time period.
period_ttl = L_centr_fnl_0.groupby('Period')\
[['Total_cycles']].sum().reset_index().sort_values('Total_cycles', ascending=0).reset_index(drop=True)

# View DataFrame.
period_ttl
# Out:
#                         Period  Total_cycles
# 0        AM peak (07:00-10:00)       4241531
# 1        PM peak (16:00-19:00)       4013456
# 2     Inter-peak (10:00-16:00)       2286218
# 3        Evening (19:00-22:00)       1766391
# 4  Early Morning (06:00-07:00)        318635

# %%
# What time period has the highest average number of cycles (every 15 mins)?
period_15mns = L_centr_fnl_0.groupby('Period')\
[['Total_cycles']].mean().round(0).reset_index().sort_values('Total_cycles', ascending=0).reset_index(drop=True)

# View DataFrame.
period_15mns
# Out:
#                         Period  Total_cycles
# 0        AM peak (07:00-10:00)          30.0
# 1        PM peak (16:00-19:00)          28.0
# 2        Evening (19:00-22:00)          12.0
# 3     Inter-peak (10:00-16:00)           8.0
# 4  Early Morning (06:00-07:00)           7.0

# %%
# Total number of cycle trips per time slot.
time_ttl = L_centr_fnl_0.groupby('Time')\
[['Total_cycles']].sum().reset_index().sort_values('Total_cycles', ascending=0).reset_index(drop=True)

# View DataFrame.
time_ttl
# Out:
#            Time  Total_cycles
# 0   0830 - 0845        565363
# 1   0845 - 0900        557032
# 2   1815 - 1830        502981
# 3   1800 - 1815        498352
# 4   1745 - 1800        492409
# ..          ...           ...
# 59  1115 - 1130         81900
# 60  2130 - 2145         71473
# 61  2145 - 2200         62273
# 62  0615 - 0630         60842
# 63  0600 - 0615         36627
#
# [64 rows x 2 columns]

# %%
# What time slot has the highest average number of cycles (every 15 mins)?
time_15mns = L_centr_fnl_0.groupby('Time')\
[['Total_cycles']].mean().round(0).reset_index().sort_values('Total_cycles', ascending=0).reset_index(drop=True)

# View DataFrame.
time_15mns
# Out:
#            Time  Total_cycles
# 0   0830 - 0845          48.0
# 1   0845 - 0900          47.0
# 2   1815 - 1830          42.0
# 3   1800 - 1815          42.0
# 4   1745 - 1800          42.0
# ..          ...           ...
# 59  1400 - 1415           7.0
# 60  2130 - 2145           6.0
# 61  2145 - 2200           5.0
# 62  0615 - 0630           5.0
# 63  0600 - 0615           3.0
#
# [64 rows x 2 columns]

# %%
# What time slot has the highest average number of cycle hire bikes (every 15 mins)?
time_hb_15mns = L_centr_fnl_0.groupby('Time')\
[['Number of cycle hire bikes']].mean().round(0).reset_index().sort_values('Number of cycle hire bikes', 
                                                                           ascending=0).reset_index(drop=True)

# View DataFrame.
time_hb_15mns
# Out:
#            Time  Number of cycle hire bikes
# 0   0830 - 0845                         5.0
# 1   0845 - 0900                         5.0
# 2   1815 - 1830                         4.0
# 3   1800 - 1815                         4.0
# 4   1745 - 1800                         4.0
# ..          ...                         ...
# 59  1415 - 1430                         1.0
# 60  1430 - 1445                         1.0
# 61  1445 - 1500                         1.0
# 62  0615 - 0630                         0.0
# 63  0600 - 0615                         0.0
#
# [64 rows x 2 columns]

# %% [markdown]
# ## Visualisations related to Date and Time

# %%
# Import the necessary libraries.
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
from matplotlib.lines import Line2D
from matplotlib.dates import MonthLocator, DateFormatter

# Set figure size.
sns.set(rc={'figure.figsize':(15, 12)})

# Set the plot style as darkgrid.
sns.set_style('darkgrid')

# %%
# Plot annualy average numbers of cycles.
# Create a lineplot.
lineplot_y = sns.lineplot(x='Survey_wave_year', y='Total_cycles', 
                           data=year_15mns, 
                           linewidth=1)

# Update title, x and y labels and legend.
lineplot_y.set_title('Average number of cycles per year', 
                      fontdict={'fontsize':20})
lineplot_y.set_xlabel('Year', fontdict={'fontsize':15})
lineplot_y.set_ylabel('Average number of cycles', fontdict={'fontsize':15})
plt.ylim(0, 19)

# View plot.
plt.show()

# %%
# Plot annualy average numbers of cycles.
# Create a lineplot.
lineplot_yq = sns.lineplot(x='Year-Quarter', y='Total_cycles', 
                           data=year_Q_15mns.sort_values('Year-Quarter', ascending=1), 
                           linewidth=1)

# Update title, x and y labels and legend.
lineplot_yq.set_title('Average number of cycles per year-quarter', 
                      fontdict={'fontsize':20})
lineplot_yq.set_xlabel('Year - Quater', fontdict={'fontsize':15})
lineplot_yq.set_ylabel('Average number of cycles', fontdict={'fontsize':15})
plt.xticks(rotation=45)
plt.ylim(0, 21)

# View plot.
plt.show()

# %%
# Plot daily average numbers of cycles.
# Create a lineplot.
lineplot_d = sns.lineplot(x='Date', y='Total_cycles', 
                           data=date_15mns, 
                           linewidth=1)

# Update title, x and y labels and legend.
lineplot_d.set_title('Average number of cycles per day', 
                      fontdict={'fontsize':20})
lineplot_d.set_xlabel('Year', fontdict={'fontsize':15})
lineplot_d.set_ylabel('Average number of cycles', fontdict={'fontsize':15})

# View plot.
plt.show()

# %%
# Plot daily average numbers of cycles per 15 min time slot.
# Create a lineplot.
lineplot_t = sns.lineplot(x='Time', y='Total_cycles', 
                           data=time_15mns.sort_values('Time', ascending=1), 
                           linewidth=1)

# Update title, x and y labels and legend.
lineplot_t.set_title('Average number of cycles per 15min time slot', 
                      fontdict={'fontsize':20})
lineplot_t.set_xlabel('15 mins time slots', fontdict={'fontsize':15})
lineplot_t.set_ylabel('Average number of cycles', fontdict={'fontsize':15})
plt.xticks(rotation=90)

# View plot.
plt.show()

# %%
# Plot daily average numbers of cycle hire bikes per 15 min time slot.
# Create a lineplot.
lineplot_t = sns.lineplot(x='Time', y='Number of cycle hire bikes', 
                           data=time_hb_15mns.sort_values('Time', ascending=1), 
                           linewidth=1)

# Update title, x and y labels and legend.
lineplot_t.set_title('Average number of cycle hire bikes per 15min time slot', 
                      fontdict={'fontsize':20})
lineplot_t.set_xlabel('15 mins time slots', fontdict={'fontsize':15})
lineplot_t.set_ylabel('Average number of cycles', fontdict={'fontsize':15})
plt.xticks(rotation=90)

# View plot.
plt.show()

# %%
# Read the provided CSV file/data set.
london_outer = pd.read_csv('Outer London.csv') 

# Print the output.
print(london_outer.info())
london_outer.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 375660 entries, 0 to 375659
# Data columns (total 14 columns):
#  #   Column                    Non-Null Count   Dtype
# ---  ------                    --------------   -----
#  0   Survey wave (year)        375660 non-null  int64
#  1   Site ID                   375660 non-null  object
#  2   Location                  375660 non-null  object
#  3   Survey date               374492 non-null  object
#  4   Weather                   374692 non-null  object
#  5   Time                      375660 non-null  object
#  6   Period                    375660 non-null  object
#  7   Direction                 375660 non-null  object
#  8   Start hour                375660 non-null  int64
#  9   Start minute              375660 non-null  int64
#  10  Number of male cycles     375660 non-null  int64
#  11  Number of female cycles   375660 non-null  int64
#  12  Number of unknown cycles  375660 non-null  int64
#  13  Total cycles              375660 non-null  int64
# dtypes: int64(7), object(7)
# memory usage: 40.1+ MB
# None
#    Survey wave (year)   Site ID          Location    Survey date Weather  \
# 0                2015  OUTCY001  High Road Leyton  ven, 26/06/15     Dry
# 1                2015  OUTCY001  High Road Leyton  ven, 26/06/15     Dry
# 2                2015  OUTCY001  High Road Leyton  ven, 26/06/15     Dry
# 3                2015  OUTCY001  High Road Leyton  ven, 26/06/15     Dry
# 4                2015  OUTCY001  High Road Leyton  ven, 26/06/15     Dry
#
#           Time                       Period   Direction  Start hour  \
# 0  0600 - 0615  Early Morning (06:00-07:00)  Northbound           6
# 1  0615 - 0630  Early Morning (06:00-07:00)  Northbound           6
# 2  0630 - 0645  Early Morning (06:00-07:00)  Northbound           6
# 3  0645 - 0700  Early Morning (06:00-07:00)  Northbound           6
# 4  0700 - 0715        AM peak (07:00-10:00)  Northbound           7
#
#    Start minute  Number of male cycles  Number of female cycles  \
# 0             0                      2                        1
# 1            15                      3                        0
# 2            30                      2                        0
# 3            45                      4                        0
# 4             0                      4                        1
#
#    Number of unknown cycles  Total cycles
# 0                         0             3
# 1                         0             3
# 2                         0             2
# 3                         0             4
# 4                         0             5

# %%
# Descriptive statistics.
london_outer.describe()
# Out:
#        Survey wave (year)     Start hour   Start minute  \
# count       375660.000000  375660.000000  375660.000000
# mean          2017.848267      13.499643      22.499840
# std              1.993641       4.609639      16.770532
# min           2015.000000       6.000000       0.000000
# 25%           2016.000000       9.000000       0.000000
# 50%           2018.000000      13.000000      15.000000
# 75%           2019.000000      17.000000      30.000000
# max           2021.000000      21.000000      45.000000
#
#        Number of male cycles  Number of female cycles  \
# count          375660.000000            375660.000000
# mean                1.335207                 0.240646
# std                 2.701113                 0.751606
# min                 0.000000                 0.000000
# 25%                 0.000000                 0.000000
# 50%                 0.000000                 0.000000
# 75%                 2.000000                 0.000000
# max                62.000000                19.000000
#
#        Number of unknown cycles   Total cycles
# count             375660.000000  375660.000000
# mean                   0.013837       1.589695
# std                    0.157072       3.165160
# min                    0.000000       0.000000
# 25%                    0.000000       0.000000
# 50%                    0.000000       0.000000
# 75%                    0.000000       2.000000
# max                   13.000000      78.000000

# %%
# Read the provided CSV file/data set.
london_inner = pd.read_csv('Inner London.csv') 

# Print the output.
print(london_inner.info())
london_inner.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 615168 entries, 0 to 615167
# Data columns (total 13 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   Survey wave (year)          523776 non-null  float64
#  1   Site ID                     523776 non-null  object
#  2   Location                    523776 non-null  object
#  3   Survey date                 521024 non-null  object
#  4   Weather                     519102 non-null  object
#  5   Time                        523770 non-null  object
#  6   Period                      523770 non-null  object
#  7   Direction                   523776 non-null  object
#  8   Start hour                  523770 non-null  float64
#  9   Start minute                523770 non-null  float64
#  10  Number of private cycles    523776 non-null  float64
#  11  Number of cycle hire bikes  523776 non-null  float64
#  12  Total cycles                523776 non-null  float64
# dtypes: float64(6), object(7)
# memory usage: 61.0+ MB
# None
#    Survey wave (year)   Site ID    Location    Survey date Weather  \
# 0              2015.0  INNCY001  Grove Road  mer, 20/05/15     Dry
# 1              2015.0  INNCY001  Grove Road  mer, 20/05/15     Dry
# 2              2015.0  INNCY001  Grove Road  mer, 20/05/15     Dry
# 3              2015.0  INNCY001  Grove Road  mer, 20/05/15     Dry
# 4              2015.0  INNCY001  Grove Road  mer, 20/05/15     Dry
#
#           Time                       Period   Direction  Start hour  \
# 0  0600 - 0615  Early Morning (06:00-07:00)  Northbound         6.0
# 1  0615 - 0630  Early Morning (06:00-07:00)  Northbound         6.0
# 2  0630 - 0645  Early Morning (06:00-07:00)  Northbound         6.0
# 3  0645 - 0700  Early Morning (06:00-07:00)  Northbound         6.0
# 4  0700 - 0715        AM peak (07:00-10:00)  Northbound         7.0
#
#    Start minute  Number of private cycles  Number of cycle hire bikes  \
# 0           0.0                       1.0                         0.0
# 1          15.0                       2.0                         0.0
# 2          30.0                       2.0                         0.0
# 3          45.0                       4.0                         0.0
# 4           0.0                       4.0                         0.0
#
#    Total cycles
# 0           1.0
# 1           2.0
# 2           2.0
# 3           4.0
# 4           4.0

# %%
london_inner.describe()
# Out:
#        Survey wave (year)     Start hour   Start minute  \
# count       523776.000000  523770.000000  523770.000000
# mean          2017.986070      13.499914      22.499914
# std              2.035381       4.609733      16.770551
# min           2015.000000       6.000000       0.000000
# 25%           2016.000000       9.000000       0.000000
# 50%           2018.000000      13.000000      15.000000
# 75%           2020.000000      17.000000      30.000000
# max           2021.000000      21.000000      45.000000
#
#        Number of private cycles  Number of cycle hire bikes   Total cycles
# count             523776.000000               523776.000000  523776.000000
# mean                   5.929833                    0.267943       6.196408
# std                   10.937833                    0.944529      11.309639
# min                    0.000000                    0.000000       0.000000
# 25%                    1.000000                    0.000000       1.000000
# 50%                    3.000000                    0.000000       3.000000
# 75%                    7.000000                    0.000000       7.000000
# max                  278.000000                   29.000000     280.000000

# %%
# Read the provided XLSX file/data set.
london_sites = pd.read_excel('Biking sites.xlsx') 

# Print the output.
print(london_sites.info())
london_sites.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2023 entries, 0 to 2022
# Data columns (total 8 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   UnqID                    2023 non-null   object
#  1   ProgID                   2023 non-null   object
#  2   SurveyDescription        2023 non-null   object
#  3   Easting                  2023 non-null   float64
#  4   Northing                 2023 non-null   float64
#  5   Location                 2023 non-null   object
#  6   Borough                  2023 non-null   object
#  7   Functional cycling area  2021 non-null   object
# dtypes: float64(2), object(6)
# memory usage: 126.6+ KB
# None
#       UnqID ProgID           SurveyDescription    Easting   Northing  \
# 0  CENCY001  CENCY  Central area cycle surveys  530251.49  178742.45
# 1  CENCY002  CENCY  Central area cycle surveys  533362.68  181824.45
# 2  CENCY003  CENCY  Central area cycle surveys  532334.06  180520.37
# 3  CENCY004  CENCY  Central area cycle surveys  532052.50  179677.64
# 4  CENCY005  CENCY  Central area cycle surveys  533031.59  180213.46
#
#                              Location         Borough Functional cycling area
# 0  Millbank (south of Thorney Street)     Westminster                 Central
# 1                         Bishopsgate  City of London                 Central
# 2                    Southwark Bridge       Southwark                 Central
# 3               Southwark Bridge Road       Southwark                 Central
# 4                       Tooley Street       Southwark                 Central

# %%
london_sites.describe()
# Out:
#              Easting       Northing
# count    2023.000000    2023.000000
# mean   530415.817094  180175.216135
# std      7926.480186    6471.406055
# min    504212.287234  158176.501703
# 25%    526356.870000  176535.431514
# 50%    530893.180000  180526.510000
# 75%    534763.484659  183589.883616
# max    558325.076719  199227.020000
