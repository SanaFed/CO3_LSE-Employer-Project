# %%
import pandas as pd
import numpy as np
from datetime import datetime

# Set max column and rows
pd.options.display.max_rows = 999
pd.options.display.max_columns = 999

#Ignore warnings.
import warnings
warnings.filterwarnings('ignore')

# Import visualisation libraries
import plotly.express as px
import matplotlib.pyplot as plt 
import seaborn as sns


# Set figure size.
sns.set(rc={'figure.figsize':(15, 12)})

# Set the plot style as darkgrid.
sns.set_style('darkgrid')

# %% [markdown]
# ## Finding total cycle counts for Inner and Outer London

# %%
# Importing files
london_inner = pd.read_csv('/Users/shin/desktop/lse_daca/final_project/data/London/london_inner_cl.csv') 
london_outer = pd.read_csv('/Users/shin/desktop/lse_daca/final_project/data/London/london_outer_cl.csv') 
london_sites = pd.read_csv('/Users/shin/desktop/lse_daca/final_project/data/London/london_sites_cl.csv')

# Subset the Inner London data from 2017-2019 timeframe.
inner_lc = london_inner.loc[(london_inner['Year'] >= 2017) & (london_inner['Year'] <= 2019)]
# Subset the Outer London data from 2017-2019 timeframe.
outer_lc = london_outer.loc[(london_outer['Survey wave (year)'] >= 2017) & (london_outer['Survey wave (year)'] <= 2019)]

# renaming columns to have a unique identifier for both datasets. 
london_sites = london_sites.rename(columns={'UnqID': 'Site ID'})

# %%
# Merge the subset with the information by borough.
inner_sites = pd.merge(inner_lc,
                 london_sites[['Site ID','Borough', 'Functional cycling area']],
                 on='Site ID', how='left')

outer_sites = pd.merge(outer_lc,
                 london_sites[['Site ID','Borough', 'Functional cycling area']],
                 on='Site ID', how='left')

# %%
outer_sites.head(2)
# Out:
#    Unnamed: 0  Survey wave (year)   Site ID          Location    Survey date  \
# 0      115456                2017  OUTCY001  High Road Leyton  mer, 07/06/17
# 1      115457                2017  OUTCY001  High Road Leyton  mer, 07/06/17
#
#   Weather         Time                       Period   Direction  Start hour  \
# 0     Dry  0600 - 0615  Early Morning (06:00-07:00)  Northbound           6
# 1     Dry  0615 - 0630  Early Morning (06:00-07:00)  Northbound           6
#
#    Start minute  Number of male cycles  Number of female cycles  \
# 0             0                      0                        0
# 1            15                      1                        0
#
#    Number of unknown cycles  Total cycles        Date        Day Month  \
# 0                         0             0  2017-06-07  Wednesday  June
# 1                         0             1  2017-06-07  Wednesday  June
#
#   Quarter         Borough Functional cycling area
# 0      Q2  Waltham Forest                   Outer
# 1      Q2  Waltham Forest                   Outer

# %%
inner_sites.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 229376 entries, 0 to 229375
# Data columns (total 21 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   Unnamed: 0                  229376 non-null  int64
#  1   Survey wave (year)          229376 non-null  int64
#  2   Site ID                     229376 non-null  object
#  3   Location                    229376 non-null  object
#  4   Survey date                 227264 non-null  object
#  5   Weather                     229376 non-null  object
#  6   Time                        229376 non-null  object
#  7   Period                      229376 non-null  object
#  8   Direction                   229376 non-null  object
#  9   Start hour                  229376 non-null  float64
#  10  Start minute                229376 non-null  float64
#  11  Number of private cycles    229376 non-null  int64
#  12  Number of cycle hire bikes  229376 non-null  int64
#  13  Total cycles                229376 non-null  int64
#  14  Date                        227264 non-null  object
#  15  Day                         227264 non-null  object
#  16  Year                        229376 non-null  int64
#  17  Month                       227264 non-null  object
#  18  Quarter                     229376 non-null  object
#  19  Borough                     229376 non-null  object
#  20  Functional cycling area     229376 non-null  object
# dtypes: float64(2), int64(6), object(13)
# memory usage: 38.5+ MB

# %%
outer_sites.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 173056 entries, 0 to 173055
# Data columns (total 21 columns):
#  #   Column                    Non-Null Count   Dtype
# ---  ------                    --------------   -----
#  0   Unnamed: 0                173056 non-null  int64
#  1   Survey wave (year)        173056 non-null  int64
#  2   Site ID                   173056 non-null  object
#  3   Location                  173056 non-null  object
#  4   Survey date               172656 non-null  object
#  5   Weather                   173056 non-null  object
#  6   Time                      173056 non-null  object
#  7   Period                    173056 non-null  object
#  8   Direction                 173056 non-null  object
#  9   Start hour                173056 non-null  int64
#  10  Start minute              173056 non-null  int64
#  11  Number of male cycles     173056 non-null  int64
#  12  Number of female cycles   173056 non-null  int64
#  13  Number of unknown cycles  173056 non-null  int64
#  14  Total cycles              173056 non-null  int64
#  15  Date                      172656 non-null  object
#  16  Day                       172656 non-null  object
#  17  Month                     172656 non-null  object
#  18  Quarter                   173056 non-null  object
#  19  Borough                   173056 non-null  object
#  20  Functional cycling area   173056 non-null  object
# dtypes: int64(8), object(13)
# memory usage: 29.0+ MB

# %%
# Determine total cycles count by inner london boroughs.
inner_cycle_count = inner_sites.groupby(['Borough', 'Year'])['Total cycles'].sum().\
                        reset_index().sort_values(by=['Borough', 'Year','Total cycles'])

# renaming column headers
inner_cycle_count.rename(columns = {'Year':'year',
                                   'Borough':'borough'}, inplace = True)

# changing column type for visualisation purposes
inner_cycle_count["year"]=group_cycle_count["year"].apply(str)

inner_cycle_count.head()
# Out:
#    borough  year  Total cycles
# 0    Brent  2017          1030
# 1    Brent  2018          1025
# 2    Brent  2019          1049
# 3  Bromley  2017           188
# 4  Bromley  2018           150

# %%
# Determine total cycles count by outer london boroughs.
outer_cycle_count = outer_sites.groupby(['Borough', 'Survey wave (year)'])['Total cycles'].sum().\
                        reset_index().sort_values(by=['Borough', 'Survey wave (year)','Total cycles'])

# renaming column headers
outer_cycle_count.rename(columns = {'Survey wave (year)':'year',
                                   'Borough':'borough'}, inplace = True)

# changing column type for visualisation purposes
outer_cycle_count["year"]=outer_cycle_count["year"].apply(str)

outer_cycle_count.head()
# Out:
#               borough  year  Total cycles
# 0  Barking & Dagenham  2017          1186
# 1  Barking & Dagenham  2018          1368
# 2  Barking & Dagenham  2019          1111
# 3              Barnet  2017          2633
# 4              Barnet  2018          2546

# %% [markdown]
# ## Finding the number of accidents in each borough

# %%
accidents = pd.read_csv('/Users/shin/desktop/lse_daca/final_project/accidents/accidents.csv')
accidents.head()
# Out:
#        id        lat       lon  \
# 0  345908  51.514951 -0.072747
# 1  345914  51.475380 -0.395505
# 2  345915  51.465106 -0.248171
# 3  345916  51.506781 -0.128527
# 4  345923  51.481538 -0.026456
#
#                                             location        date      time  \
# 0  On Whitechapel High Street Near The Junction W...  2019-01-02  18:45:00
# 1  On Great west Road Near The Junction With Grea...  2019-01-03  06:45:00
# 2  On Upper Richmond Road Near The Junction With ...  2019-01-03  12:30:00
# 3  On The Mall 50 metres west of The Junction Wit...  2019-01-03  10:45:00
# 4  On New King Street Near The Junction With Evel...  2019-01-03  17:00:00
#
#     area               borough         mode  year
# 0  Inner         Tower Hamlets   PedalCycle  2019
# 1  Outer              Hounslow   PedalCycle  2019
# 2  Outer  Richmond upon Thames   PedalCycle  2019
# 3  Inner           Westminster   PedalCycle  2019
# 4  Inner              Lewisham   PedalCycle  2019

# %%
accidents.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26455 entries, 0 to 26454
# Data columns (total 10 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   id        26455 non-null  int64
#  1   lat       26455 non-null  float64
#  2   lon       26455 non-null  float64
#  3   location  26455 non-null  object
#  4   date      26455 non-null  object
#  5   time      26455 non-null  object
#  6   area      26455 non-null  object
#  7   borough   26455 non-null  object
#  8   mode      26455 non-null  object
#  9   year      26455 non-null  int64
# dtypes: float64(2), int64(2), object(6)
# memory usage: 2.0+ MB

# %%
# changing the year column into categorical for visualisation purposes.
accidents['year'] = accidents['year'].astype(str)
accidents.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26455 entries, 0 to 26454
# Data columns (total 10 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   id        26455 non-null  int64
#  1   lat       26455 non-null  float64
#  2   lon       26455 non-null  float64
#  3   location  26455 non-null  object
#  4   date      26455 non-null  object
#  5   time      26455 non-null  object
#  6   area      26455 non-null  object
#  7   borough   26455 non-null  object
#  8   mode      26455 non-null  object
#  9   year      26455 non-null  object
# dtypes: float64(2), int64(1), object(7)
# memory usage: 2.0+ MB

# %%
# renaming column header for clarity
accidents.rename(columns = {'mode': 'total_accidents'}, inplace = True)

# %%
# Finding the number of pedalcycle accidents in each borough and year.
accidents_count = accidents.groupby(['year','borough', 'area'])[['total_accidents']].count().reset_index()
accidents_count.head()
# Out:
#    year             borough   area  total_accidents
# 0  2017  Barking & Dagenham  Outer               82
# 1  2017              Barnet  Outer              118
# 2  2017              Bexley  Outer               36
# 3  2017               Brent  Outer              170
# 4  2017             Bromley  Outer              184

# %%
# merging inner london total cycle counts and inner london accident total counts
accidents_totalcycle_inner = pd.merge(inner_cycle_count, accidents_count, on=['borough','year'], how='left')


accidents_totalcycle_inner.head()
# Out:
#    borough  year  Total cycles   area  total_accidents
# 0    Brent  2017          1030  Outer            170.0
# 1    Brent  2018          1025  Outer            164.0
# 2    Brent  2019          1049  Outer            152.0
# 3  Bromley  2017           188  Outer            184.0
# 4  Bromley  2018           150  Outer            162.0

# %%
accidents_totalcycle_inner.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 63 entries, 0 to 62
# Data columns (total 5 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   borough          63 non-null     object
#  1   year             24 non-null     object
#  2   Total cycles     63 non-null     int64
#  3   area             24 non-null     object
#  4   total_accidents  24 non-null     float64
# dtypes: float64(1), int64(1), object(3)
# memory usage: 3.0+ KB

# %%
# checking for null values
accidents_totalcycle_inner.total_accidents.isnull().sum()
# Out:
# 39

# %%
accidents_totalcycle_inner_cl = accidents_totalcycle_inner.dropna()
accidents_totalcycle_inner_cl.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 24 entries, 0 to 23
# Data columns (total 5 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   borough          24 non-null     object
#  1   year             24 non-null     object
#  2   Total cycles     24 non-null     int64
#  3   area             24 non-null     object
#  4   total_accidents  24 non-null     float64
# dtypes: float64(1), int64(1), object(3)
# memory usage: 1.1+ KB

# %%
# merging inner london total cycle counts and inner london accident total counts
accidents_totalcycle_outer = pd.merge(outer_cycle_count, accidents_count, on=['borough','year'], how='left')

accidents_totalcycle_outer.head()
# Out:
#               borough  year  Total cycles   area  total_accidents
# 0  Barking & Dagenham  2017          1186  Outer               82
# 1  Barking & Dagenham  2018          1368  Outer               82
# 2  Barking & Dagenham  2019          1111  Outer              114
# 3              Barnet  2017          2633  Outer              118
# 4              Barnet  2018          2546  Outer              151

# %%
# checking for null values
accidents_totalcycle_outer.total_accidents.isnull().sum()
# Out:
# 0

# %% [markdown]
# ## Visualising the results

# %%
# df = accidents_count[accidents_count['area'] == 'Inner']

df = accidents_totalcycle_inner_cl

fig = px.bar(df,
             x="borough",
             y="total_accidents",
             color="year",
             labels={"borough": "Borough",
                     "total_accidents": "Number of accidents"},
             title="Cyclist accidents in Inner London from 2017 to 2019")
fig.show()
# Out:
# <div>                            <div id="63fad306-ad9d-4338-9901-f51741097d81" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("63fad306-ad9d-4338-9901-f51741097d81")) {                    Plotly.newPlot(                        "63fad306-ad9d-4338-9901-f51741097d81",                        [{"alignmentgroup": "True", "hovertemplate": "year=2017<br>Borough=%{x}<br>Number of accidents=%{y}<extra></extra>", "legendgroup": "2017", "marker": {"color": "#636efa"}, "name": "2017", "offsetgroup": "2017", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["Brent", "Bromley", "Camden", "Ealing", "Greenwich", "Hackney", "Hammersmith & Fulham", "Haringey"], "xaxis": "x", "y": [170.0, 184.0, 476.0, 192.0, 186.0, 464.0, 342.0, 250.0], "yaxis": "y"}, {"alignmentgroup": "True", "hovertemplate": "year=2018<br>Borough=%{x}<br>Number of accidents=%{y}<extra></extra>", "legendgroup": "2018", "marker": {"color": "#EF553B"}, "name": "2018", "offsetgroup": "2018", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["Brent", "Bromley", "Camden", "Ealing", "Greenwich", "Hackney", "Hammersmith & Fulham", "Haringey"], "xaxis": "x", "y": [164.0, 162.0, 480.0, 216.0, 204.0, 474.0, 344.0, 208.0], "yaxis": "y"}, {"alignmentgroup": "True", "hovertemplate": "year=2019<br>Borough=%{x}<br>Number of accidents=%{y}<extra></extra>", "legendgroup": "2019", "marker": {"color": "#00cc96"}, "name": "2019", "offsetgroup": "2019", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["Brent", "Bromley", "Camden", "Ealing", "Greenwich", "Hackney", "Hammersmith & Fulham", "Haringey"], "xaxis": "x", "y": [152.0, 190.0, 466.0, 230.0, 162.0, 418.0, 298.0, 240.0], "yaxis": "y"}],                        {"barmode": "relative", "legend": {"title": {"text": "year"}, "tracegroupgap": 0}, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"],  ...

# %%
df1 = accidents_totalcycle_outer

fig = px.bar(df1,
             x="borough",
             y="total_accidents",
             color="year",
             labels={"borough": "Borough",
                     "total_accidents": "Number of accidents"},
             title="Cyclist accidents in Outer London from 2017 to 2019")
fig.show()
# Out:
# <div>                            <div id="428ff542-f2da-4063-adec-5a7e24d15c70" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("428ff542-f2da-4063-adec-5a7e24d15c70")) {                    Plotly.newPlot(                        "428ff542-f2da-4063-adec-5a7e24d15c70",                        [{"alignmentgroup": "True", "hovertemplate": "year=2017<br>Borough=%{x}<br>Number of accidents=%{y}<extra></extra>", "legendgroup": "2017", "marker": {"color": "#636efa"}, "name": "2017", "offsetgroup": "2017", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["Barking & Dagenham", "Barnet", "Bexley", "Brent", "Bromley", "Croydon", "Ealing", "Enfield", "Greenwich", "Haringey", "Harrow", "Havering", "Hillingdon", "Hounslow", "Kingston upon Thames", "Lambeth", "Lewisham", "Merton", "Newham", "Redbridge", "Richmond upon Thames", "Sutton", "Waltham Forest", "Wandsworth"], "xaxis": "x", "y": [82, 118, 36, 170, 184, 134, 192, 100, 186, 250, 62, 62, 72, 218, 152, 640, 262, 140, 172, 124, 260, 76, 186, 538], "yaxis": "y"}, {"alignmentgroup": "True", "hovertemplate": "year=2018<br>Borough=%{x}<br>Number of accidents=%{y}<extra></extra>", "legendgroup": "2018", "marker": {"color": "#EF553B"}, "name": "2018", "offsetgroup": "2018", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["Barking & Dagenham", "Barnet", "Bexley", "Brent", "Bromley", "Croydon", "Ealing", "Enfield", "Greenwich", "Haringey", "Harrow", "Havering", "Hillingdon", "Hounslow", "Kingston upon Thames", "Lambeth", "Lewisham", "Merton", "Newham", "Redbridge", "Richmond upon Thames", "Sutton", "Waltham Forest", "Wandsworth"], "xaxis": "x", "y": [82, 151, 66, 164, 162, 172, 216, 96, 204, 208, 80, 88, 104, 240, 168, 650, 308, 158, 202, 108, 256, 72, 214, 550], "yaxis": "y"}, {"alignmentgroup": "True", "hovertemplate": "year=2019<br>Borough=%{x}<br>Number of accidents=%{y}<extra></extra>", "legendgroup": "2019", "marker": {"color": "#00cc96"}, "name": "2019", "offsetgroup": "2019", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["Barking & Dagenham", "Barnet", "Bexley", "Brent", "Bromley", "Croydon", "Ealing", "Enfield", "Greenwich", "Haringey", "Harrow", "Havering", "Hillingdon", "Hounslow", "Kingston upon Thames", "Lambeth", "Lewisham", "Merton", "Newham", "Redbridge", "Richmond upon Thames", "Sutton", "Waltham Forest", "Wandsworth"], "xaxis": "x", "y": [114, 122, 64, 152, 190, 168, 230, 96, 162, 240, 62, 60, 114, 230, 138, 584, 300, 158, 194, 116, 256, 106, 234, 492], "yaxis": "y"}],                        {"barmode": "relative", "legend": {"title": {"text": "year"}, "tracegroupgap": 0}, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar":  ...

# %%
# Inner london total cycles vs accidents
fig = px.scatter(accidents_totalcycle_inner_cl,
                 x='Total cycles',
                 y='total_accidents',
                 color='year',
                 labels={"Total cycles": "Number of cycles",
                         "total_accidents": "Number of accidents"},
                 title="Relationship between cycling and accidents in Inner London from 2017 to 2019")
fig.show()
# Out:
# <div>                            <div id="d48fd561-d446-4943-959f-06dc56b541dc" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("d48fd561-d446-4943-959f-06dc56b541dc")) {                    Plotly.newPlot(                        "d48fd561-d446-4943-959f-06dc56b541dc",                        [{"hovertemplate": "year=2017<br>Number of cycles=%{x}<br>Number of accidents=%{y}<extra></extra>", "legendgroup": "2017", "marker": {"color": "#636efa", "symbol": "circle"}, "mode": "markers", "name": "2017", "orientation": "v", "showlegend": true, "type": "scatter", "x": [1030, 188, 25961, 3067, 80, 52996, 39616, 4843], "xaxis": "x", "y": [170.0, 184.0, 476.0, 192.0, 186.0, 464.0, 342.0, 250.0], "yaxis": "y"}, {"hovertemplate": "year=2018<br>Number of cycles=%{x}<br>Number of accidents=%{y}<extra></extra>", "legendgroup": "2018", "marker": {"color": "#EF553B", "symbol": "circle"}, "mode": "markers", "name": "2018", "orientation": "v", "showlegend": true, "type": "scatter", "x": [1025, 150, 25837, 1822, 49, 53583, 41467, 5300], "xaxis": "x", "y": [164.0, 162.0, 480.0, 216.0, 204.0, 474.0, 344.0, 208.0], "yaxis": "y"}, {"hovertemplate": "year=2019<br>Number of cycles=%{x}<br>Number of accidents=%{y}<extra></extra>", "legendgroup": "2019", "marker": {"color": "#00cc96", "symbol": "circle"}, "mode": "markers", "name": "2019", "orientation": "v", "showlegend": true, "type": "scatter", "x": [1049, 251, 24184, 2232, 106, 53449, 42337, 4350], "xaxis": "x", "y": [152.0, 190.0, 466.0, 230.0, 162.0, 418.0, 298.0, 240.0], "yaxis": "y"}],                        {"legend": {"title": {"text": "year"}, "tracegroupgap": 0}, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111 ...

# %%
# Outer london total cycles vs accidents
fig = px.scatter(accidents_totalcycle_outer,
                 x='Total cycles',
                 y='total_accidents',
                 color='year',
                 labels={"Total cycles": "Number of cycles",
                         "total_accidents": "Number of accidents"},
                 title="Relationship between cycling and accidents in Outer London from 2017 to 2019")
fig.show()
# Out:
# <div>                            <div id="6dc8fa3e-fa66-442d-b251-f030d1dface4" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("6dc8fa3e-fa66-442d-b251-f030d1dface4")) {                    Plotly.newPlot(                        "6dc8fa3e-fa66-442d-b251-f030d1dface4",                        [{"hovertemplate": "year=2017<br>Number of cycles=%{x}<br>Number of accidents=%{y}<extra></extra>", "legendgroup": "2017", "marker": {"color": "#636efa", "symbol": "circle"}, "mode": "markers", "name": "2017", "orientation": "v", "showlegend": true, "type": "scatter", "x": [1186, 2633, 1168, 4107, 2870, 2874, 6610, 1971, 3376, 3917, 837, 1840, 3778, 7370, 6352, 235, 4663, 4701, 6173, 1779, 11351, 2686, 4040, 71], "xaxis": "x", "y": [82, 118, 36, 170, 184, 134, 192, 100, 186, 250, 62, 62, 72, 218, 152, 640, 262, 140, 172, 124, 260, 76, 186, 538], "yaxis": "y"}, {"hovertemplate": "year=2018<br>Number of cycles=%{x}<br>Number of accidents=%{y}<extra></extra>", "legendgroup": "2018", "marker": {"color": "#EF553B", "symbol": "circle"}, "mode": "markers", "name": "2018", "orientation": "v", "showlegend": true, "type": "scatter", "x": [1368, 2546, 1094, 4017, 2791, 2824, 7622, 1829, 3277, 4024, 1080, 1640, 4379, 7183, 6746, 220, 5067, 5873, 6643, 1908, 12105, 2896, 4755, 79], "xaxis": "x", "y": [82, 151, 66, 164, 162, 172, 216, 96, 204, 208, 80, 88, 104, 240, 168, 650, 308, 158, 202, 108, 256, 72, 214, 550], "yaxis": "y"}, {"hovertemplate": "year=2019<br>Number of cycles=%{x}<br>Number of accidents=%{y}<extra></extra>", "legendgroup": "2019", "marker": {"color": "#00cc96", "symbol": "circle"}, "mode": "markers", "name": "2019", "orientation": "v", "showlegend": true, "type": "scatter", "x": [1111, 2773, 1056, 3553, 2650, 2718, 7455, 1561, 3072, 3743, 797, 1344, 3489, 6433, 5882, 185, 4796, 4294, 6144, 1426, 10730, 2417, 4421, 67], "xaxis": "x", "y": [114, 122, 64, 152, 190, 168, 230, 96, 162, 240, 62, 60, 114, 230, 138, 584, 300, 158, 194, 116, 256, 106, 234, 492], "yaxis": "y"}],                        {"legend": {"title": {"text": "year"}, "tracegroupgap": 0}, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.22222222222222 ...

# %% [markdown]
# There is a plausible positive relationship that the number of accidents increases as the number of cycles increases in both Inner and Outer London. There are relatively minimal changes over the years in terms of this relationship. More could be done to reduce the number of accidents as we move forward to increase the number of cycles in the future. Next, we look how these accidents are reported to TFL to gain some insights into some causes of the accidents.

# %%
## creating a word cloud to visualise the most common location that have frequent accidents in london
from textblob import TextBlob
from wordcloud import WordCloud
import nltk
nltk.download('punkt')
from nltk.tokenize import word_tokenize
from nltk.tokenize import sent_tokenize
# Import the class.
from nltk.probability import FreqDist
# Out:
# [nltk_data] Downloading package punkt to /Users/shin/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
# Transform data to lowercase.
accidents['location'] = accidents['location'].apply(lambda x: " ".join(x.lower() for x in x.split()))

# Preview the result.
accidents['location'].head()
# Out:
# 0    on whitechapel high street near the junction w...
# 1    on great west road near the junction with grea...
# 2    on upper richmond road near the junction with ...
# 3    on the mall 50 metres west of the junction wit...
# 4    on new king street near the junction with evel...
# Name: location, dtype: object

# %%
# Remove punctuation.
accidents['location'] = accidents['location'].str.replace('[^\w\s]','')

# Preview the result.
accidents['location'].head()
# Out:
# 0    on whitechapel high street near the junction w...
# 1    on great west road near the junction with grea...
# 2    on upper richmond road near the junction with ...
# 3    on the mall 50 metres west of the junction wit...
# 4    on new king street near the junction with evel...
# Name: location, dtype: object

# %%
# Check the number of duplicate values in the COMMENTS column.
accidents.location.duplicated().sum()
# Out:
# 14330

# %%
# Drop duplicates.
accidents_data = accidents.drop_duplicates(subset=['location'])

# Preview data.
accidents_data.reset_index(inplace=True)
accidents_data.head()
# Out:
#    index      id        lat       lon  \
# 0      0  345908  51.514951 -0.072747
# 1      1  345914  51.475380 -0.395505
# 2      2  345915  51.465106 -0.248171
# 3      3  345916  51.506781 -0.128527
# 4      4  345923  51.481538 -0.026456
#
#                                             location        date      time  \
# 0  on whitechapel high street near the junction w...  2019-01-02  18:45:00
# 1  on great west road near the junction with grea...  2019-01-03  06:45:00
# 2  on upper richmond road near the junction with ...  2019-01-03  12:30:00
# 3  on the mall 50 metres west of the junction wit...  2019-01-03  10:45:00
# 4  on new king street near the junction with evel...  2019-01-03  17:00:00
#
#     area               borough         mode  year
# 0  Inner         Tower Hamlets   PedalCycle  2019
# 1  Outer              Hounslow   PedalCycle  2019
# 2  Outer  Richmond upon Thames   PedalCycle  2019
# 3  Inner           Westminster   PedalCycle  2019
# 4  Inner              Lewisham   PedalCycle  2019

# %%
# String all the comments together in a single variable.
# Create an empty string variable.
all_location = ''
for i in range(accidents_data.shape[0]):
    # Add each location.
    all_location = all_location + accidents_data['location'][i]

# %%
all_location
# Out:
# 'on whitechapel high street near the junction with old castle streon great west road near the junction with great south west road north ofon upper richmond road near the junction with priory laneon the mall 50 metres west of the junction with spring gardenson new king street near the junction with evelyn streeton stanley avenue near the junction with whalebone lane southon kingston road london sw19 near the junction with church laneon kingston bypass 200 metres north of the junction with coombe lon campbell road near the junction with bow road londonon eardley road near the junction with mitcham laneon crowndale road nw1 58 metres east of the junction with camdenon kensington road 20 metres west of the junction with palace avenueon kings road near the junction with oakly streeton hove gardens near the junction with naon warren road near the junction with windsor driveon horn lane 20 metres north of the junction with shalimar gardenon lavender sweep near the junction with lavender hillon kensington high street 50 metres west of the junction with addon bow road near the junction with arnold roadon sutherland avenue near the junction with maida valeon kilburn high road near the junction with victoria roadon wellington street near the junction with exeter streeton sheen road richmond surrey near the junction with church roaon kingston road 10 metres south of the junction with ferry roadbridge view near the junction with bridge viewon garratt lane 25 metres north of the junction with smallwood roon buckland road near the junction with pittfield streeton cranbrook road near the junction with shere roadon highbury grove near the junction with highbury groveon rosendale road near the junction with guernsey roadon southwark street near the junction with hopton streeton queens gate 10 metres north of the junction with old bromptonon camden road near the junction with rochester toadon hampstead lane near the junction with north roadon deal porters way near the junction with middle of surrey quaysuncertain location  on uxbridge road hayes near the junction wion high street near the junction with park roadon achilles close 50 metres east of the junction with abercorn waon camberwell new road near the junction with lothian roadon bloomsbury way 25 metres east of the junction with bury placeon peckham high street near the junction with bellenden roadon cross street near the junction with upper streeton ailsa road 72 metres west of the junction with st margarets dron chelsea bridge 168 metres south of the junction with grosvenoron mollison drive 100 metres north of the junction with roe wayon charlmont road near the junction with sellincourt roadon clapham road near the junction with jeffreys roadon kensington high street near the junction with eden closeon thurleigh road near the junction with hillier roadon hayes lane near the junction with hayes roadon east india dock road near the junction with cotton streetlocation uncertain on high road near the junction with high roadon russell gardens near the junction with russel roadon prince albert road 20 metres west of the junction with alberton bath road near the junction with legrace avenueon robin hood way near the junction with kingston bypasson high street feltham 30 metres north of the junction with bedfoon bridgewater road near the junction with manor farm roadon clapham high street near the junction with edgley eoadon west end lane 50 metres south of the junction with sumatra roaon green wrythe lane near the junction with buckhurst avenueon tufnell park road near the junction with huddleston roadon station road near the junction with forest driveon kings road near the junction with lots roadon lewisham way near the junction with florence roadon putney high street near the junction with putney bridge roadon cambridge heath road 25 metres east of the junction with paradon caledonian road near the junction with stock orchard streeton southwark street near the junction with southwark bridge r ...

# %%
# Set the colour palette.
sns.set(color_codes=True)

# Create a WordCloud object.
word_cloud = WordCloud(width = 1600, height = 900,
                background_color ='white',
                colormap = 'plasma', 
                stopwords = 'none',
                min_font_size = 10).generate(all_location)

# %%
# Plot the WordCloud image.                    
plt.figure(figsize = (16, 9), facecolor = None) 
plt.imshow(word_cloud) 
plt.axis('off') 
plt.tight_layout(pad = 0) 
plt.show()

# %%
# tokenising the text data

# %%
tokenised_sentence = sent_tokenize(all_location)

# Check the result.
print(tokenised_sentence)
# Out:
# ['on whitechapel high street near the junction with old castle streon great west road near the junction with great south west road north ofon upper richmond road near the junction with priory laneon the mall 50 metres west of the junction with spring gardenson new king street near the junction with evelyn streeton stanley avenue near the junction with whalebone lane southon kingston road london sw19 near the junction with church laneon kingston bypass 200 metres north of the junction with coombe lon campbell road near the junction with bow road londonon eardley road near the junction with mitcham laneon crowndale road nw1 58 metres east of the junction with camdenon kensington road 20 metres west of the junction with palace avenueon kings road near the junction with oakly streeton hove gardens near the junction with naon warren road near the junction with windsor driveon horn lane 20 metres north of the junction with shalimar gardenon lavender sweep near the junction with lavender hillon kensington high street 50 metres west of the junction with addon bow road near the junction with arnold roadon sutherland avenue near the junction with maida valeon kilburn high road near the junction with victoria roadon wellington street near the junction with exeter streeton sheen road richmond surrey near the junction with church roaon kingston road 10 metres south of the junction with ferry roadbridge view near the junction with bridge viewon garratt lane 25 metres north of the junction with smallwood roon buckland road near the junction with pittfield streeton cranbrook road near the junction with shere roadon highbury grove near the junction with highbury groveon rosendale road near the junction with guernsey roadon southwark street near the junction with hopton streeton queens gate 10 metres north of the junction with old bromptonon camden road near the junction with rochester toadon hampstead lane near the junction with north roadon deal porters way near the junction with middle of surrey quaysuncertain location  on uxbridge road hayes near the junction wion high street near the junction with park roadon achilles close 50 metres east of the junction with abercorn waon camberwell new road near the junction with lothian roadon bloomsbury way 25 metres east of the junction with bury placeon peckham high street near the junction with bellenden roadon cross street near the junction with upper streeton ailsa road 72 metres west of the junction with st margarets dron chelsea bridge 168 metres south of the junction with grosvenoron mollison drive 100 metres north of the junction with roe wayon charlmont road near the junction with sellincourt roadon clapham road near the junction with jeffreys roadon kensington high street near the junction with eden closeon thurleigh road near the junction with hillier roadon hayes lane near the junction with hayes roadon east india dock road near the junction with cotton streetlocation uncertain on high road near the junction with high roadon russell gardens near the junction with russel roadon prince albert road 20 metres west of the junction with alberton bath road near the junction with legrace avenueon robin hood way near the junction with kingston bypasson high street feltham 30 metres north of the junction with bedfoon bridgewater road near the junction with manor farm roadon clapham high street near the junction with edgley eoadon west end lane 50 metres south of the junction with sumatra roaon green wrythe lane near the junction with buckhurst avenueon tufnell park road near the junction with huddleston roadon station road near the junction with forest driveon kings road near the junction with lots roadon lewisham way near the junction with florence roadon putney high street near the junction with putney bridge roadon cambridge heath road 25 metres east of the junction with paradon caledonian road near the junction with stock orchard streeton southwark street near the junction with southwark bridge  ...

# %%
# Tokenise the text data.
tokenised_word = word_tokenize(all_location)

# Check the result.
print(tokenised_word)
# Out:
# ['on', 'whitechapel', 'high', 'street', 'near', 'the', 'junction', 'with', 'old', 'castle', 'streon', 'great', 'west', 'road', 'near', 'the', 'junction', 'with', 'great', 'south', 'west', 'road', 'north', 'ofon', 'upper', 'richmond', 'road', 'near', 'the', 'junction', 'with', 'priory', 'laneon', 'the', 'mall', '50', 'metres', 'west', 'of', 'the', 'junction', 'with', 'spring', 'gardenson', 'new', 'king', 'street', 'near', 'the', 'junction', 'with', 'evelyn', 'streeton', 'stanley', 'avenue', 'near', 'the', 'junction', 'with', 'whalebone', 'lane', 'southon', 'kingston', 'road', 'london', 'sw19', 'near', 'the', 'junction', 'with', 'church', 'laneon', 'kingston', 'bypass', '200', 'metres', 'north', 'of', 'the', 'junction', 'with', 'coombe', 'lon', 'campbell', 'road', 'near', 'the', 'junction', 'with', 'bow', 'road', 'londonon', 'eardley', 'road', 'near', 'the', 'junction', 'with', 'mitcham', 'laneon', 'crowndale', 'road', 'nw1', '58', 'metres', 'east', 'of', 'the', 'junction', 'with', 'camdenon', 'kensington', 'road', '20', 'metres', 'west', 'of', 'the', 'junction', 'with', 'palace', 'avenueon', 'kings', 'road', 'near', 'the', 'junction', 'with', 'oakly', 'streeton', 'hove', 'gardens', 'near', 'the', 'junction', 'with', 'naon', 'warren', 'road', 'near', 'the', 'junction', 'with', 'windsor', 'driveon', 'horn', 'lane', '20', 'metres', 'north', 'of', 'the', 'junction', 'with', 'shalimar', 'gardenon', 'lavender', 'sweep', 'near', 'the', 'junction', 'with', 'lavender', 'hillon', 'kensington', 'high', 'street', '50', 'metres', 'west', 'of', 'the', 'junction', 'with', 'addon', 'bow', 'road', 'near', 'the', 'junction', 'with', 'arnold', 'roadon', 'sutherland', 'avenue', 'near', 'the', 'junction', 'with', 'maida', 'valeon', 'kilburn', 'high', 'road', 'near', 'the', 'junction', 'with', 'victoria', 'roadon', 'wellington', 'street', 'near', 'the', 'junction', 'with', 'exeter', 'streeton', 'sheen', 'road', 'richmond', 'surrey', 'near', 'the', 'junction', 'with', 'church', 'roaon', 'kingston', 'road', '10', 'metres', 'south', 'of', 'the', 'junction', 'with', 'ferry', 'roadbridge', 'view', 'near', 'the', 'junction', 'with', 'bridge', 'viewon', 'garratt', 'lane', '25', 'metres', 'north', 'of', 'the', 'junction', 'with', 'smallwood', 'roon', 'buckland', 'road', 'near', 'the', 'junction', 'with', 'pittfield', 'streeton', 'cranbrook', 'road', 'near', 'the', 'junction', 'with', 'shere', 'roadon', 'highbury', 'grove', 'near', 'the', 'junction', 'with', 'highbury', 'groveon', 'rosendale', 'road', 'near', 'the', 'junction', 'with', 'guernsey', 'roadon', 'southwark', 'street', 'near', 'the', 'junction', 'with', 'hopton', 'streeton', 'queens', 'gate', '10', 'metres', 'north', 'of', 'the', 'junction', 'with', 'old', 'bromptonon', 'camden', 'road', 'near', 'the', 'junction', 'with', 'rochester', 'toadon', 'hampstead', 'lane', 'near', 'the', 'junction', 'with', 'north', 'roadon', 'deal', 'porters', 'way', 'near', 'the', 'junction', 'with', 'middle', 'of', 'surrey', 'quaysuncertain', 'location', 'on', 'uxbridge', 'road', 'hayes', 'near', 'the', 'junction', 'wion', 'high', 'street', 'near', 'the', 'junction', 'with', 'park', 'roadon', 'achilles', 'close', '50', 'metres', 'east', 'of', 'the', 'junction', 'with', 'abercorn', 'waon', 'camberwell', 'new', 'road', 'near', 'the', 'junction', 'with', 'lothian', 'roadon', 'bloomsbury', 'way', '25', 'metres', 'east', 'of', 'the', 'junction', 'with', 'bury', 'placeon', 'peckham', 'high', 'street', 'near', 'the', 'junction', 'with', 'bellenden', 'roadon', 'cross', 'street', 'near', 'the', 'junction', 'with', 'upper', 'streeton', 'ailsa', 'road', '72', 'metres', 'west', 'of', 'the', 'junction', 'with', 'st', 'margarets', 'dron', 'chelsea', 'bridge', '168', 'metres', 'south', 'of', 'the', 'junction', 'with', 'grosvenoron', 'mollison', 'drive', '100', 'metres', 'north', 'of', 'the', 'junction', 'with', 'roe', 'wayon', 'charlmont', 'road', 'near', 'the', 'junction', 'with', 'sellincourt', 'roadon', 'clapham', 'road', 'near',  ...

# %%
# Create a frequency distribution object.
freq_dist_of_words = FreqDist(tokenised_word)

# Show the five most common elements in the data set.
freq_dist_of_words.most_common(10)
# Out:
# [('junction', 11898),
#  ('with', 11853),
#  ('road', 6887),
#  ('the', 4234),
#  ('of', 3189),
#  ('metres', 3156),
#  ('near', 2945),
#  ('street', 2125),
#  ('roadon', 1292),
#  ('north', 1159)]

# %%
# Define the figure and axes.
fig, ax = plt.subplots(dpi=100)
fig.set_size_inches(12, 12)

# Plot the data set.
freq_dist_of_words.plot(30, cumulative=False)

# Display the result.
plt.show()

# %% [markdown]
# It appears that the location in which accidents commonly occur and/or reported in London are at junctions.
# Hence, one way to decrease the number of accidents would be to look into the sufficiency of infrastructures where accidents occured.
